# %%
# The line below sets the environment
# variable CUDA_VISIBLE_DEVICES
# %env CUDA_VISIBLE_DEVICES = 1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import multiprocessing as mp      # will come in handy due to the size of the data
import os.path
import random
import io
from datetime import datetime
import gc # garbage collector
import sklearn
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
import math
from collections import defaultdict
import re

# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# env: CUDA_VISIBLE_DEVICES=1
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATASET_PATH = '/media/rs/0E06CD1706CD0127/Kapok/WSDM/'
TRAIN_FILE = DATASET_PATH + 'train.csv'
TEST_FILE = DATASET_PATH + 'test.csv'
MEMBER_FILE = DATASET_PATH + 'members.csv'
SONG_FILE = DATASET_PATH + 'songs.csv'
SONG_EXTRA_FILE = DATASET_PATH + 'song_extra_info.csv'

# %%
train_data = pd.read_csv(TRAIN_FILE)
test_data = pd.read_csv(TEST_FILE)

# %%
member_data = pd.read_csv(MEMBER_FILE)
song_data = pd.read_csv(SONG_FILE)
song_extra_data = pd.read_csv(SONG_EXTRA_FILE)

# %%
def preprocess_csv_file(input_data, col_index):
    all_df = pd.DataFrame(data = None, columns=input_data.columns)
    num_col = len(input_data.columns)
    row_to_drop = list()
    for cur_row in input_data.itertuples():
        if isinstance(cur_row[col_index], str): 
            if '\n' in cur_row[col_index]:
                cur_prefix = list(cur_row)[1:col_index]          
                next_suffix = list(cur_row)[col_index + 1:]
                multi_line_list = cur_row[col_index].split('\n')
                # this is the current one, merged mannually
                all_df = all_df.append(pd.DataFrame([cur_prefix + multi_line_list[0].split(',')], columns = input_data.columns).replace(r'', np.nan), ignore_index=True)
                # this is the last one, merged mannually
                all_df = all_df.append(pd.DataFrame([multi_line_list[-1].split(',') + next_suffix], columns = input_data.columns).replace(r'', np.nan), ignore_index=True)
                # these are central ones
                for cur_record in multi_line_list[1:-1]:
                    #pass
                    all_df = all_df.append(pd.DataFrame([cur_record.split(',')], columns = input_data.columns).replace(r'', np.nan), ignore_index=True)             
                row_to_drop.append(cur_row[0])
    print('{} fixed.'.format(len(all_df.index)))
    input_data.drop(input_data.index[row_to_drop], inplace=True)
    #print(all_df)
    return input_data.append(all_df, ignore_index=True)

# %%
# artist_name 4, composer 5, lyricist 6
song_data = preprocess_csv_file(song_data, 4)     
song_data = preprocess_csv_file(song_data, 5) 
song_data = preprocess_csv_file(song_data, 6) 
song_data.to_csv(DATASET_PATH + 'fix_songs.csv', index=False, sep=',')
# Out:
# 435 fixed.
# 82 fixed.
# 0 fixed.

# %%
# for col_index in songs.csv: artist_name 4, composer 5, lyricist 6
# for other file please print the first tuple to check the index
def split_and_strip_append(input_data, column, col_index, save_file_name):
    all_df = pd.DataFrame(data = None, columns=[column])
    step = 0
    #for cur_row in input_data.iterrows():
    for cur_row in input_data.itertuples():
        if isinstance(cur_row[col_index], str): 
            df = pd.DataFrame([s.strip(' \"\t\s\n') for s in re.split(r'[|/]+',cur_row[col_index])], columns=[column])
            all_df = all_df.append(df, ignore_index=True)
            step += 1
            #break
            if step > 10000:
                if not os.path.isfile(save_file_name):
                    all_df.to_csv(save_file_name, mode='a', index=False, sep=' ')
                else:
                    all_df.to_csv(save_file_name, mode='a', index=False, sep=' ', header=False)
                all_df = pd.DataFrame(data = None, columns=[column])
    all_df.to_csv(save_file_name, mode='a', index=False, sep=' ', header=False)
    return all_df

# %%
def split_and_strip(input_data, column, col_index):
    all_df = pd.DataFrame(data = None, columns=[column])
    for cur_row in input_data.itertuples():
        if isinstance(cur_row[col_index], str): 
            df = pd.DataFrame([s.strip(' \"\t\s\n') for s in re.split(r'[|/]+',cur_row[col_index])], columns=[column])
            all_df = all_df.append(df, ignore_index=True)
            #break
    return all_df

# %%
# print(member_data.set_index('msno').reindex(['XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=','XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=','XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=']))

# %%
print(song_extra_data.head())
# Out:
#                                         song_id             name          isrc
# 0  LP7pLJoJFBvyuUwvu+oLzjT+bI+UeBPURCecJsX1jjs=               我們  TWUM71200043
# 1  ClazTFnk6r0Bnuie44bocdNMM3rdlrq0bCGAsGUWcHE=  Let Me Love You  QMZSY1600015
# 2  u2ja/bZE3zhCGxvbbOB3zOoUjx27u40cf5g09UXMoKQ=              原諒我  TWA530887303
# 3  92Fqsy0+p6+RHe2EoLKjHahORHR1Kq1TBJoClW9v+Ts=          Classic  USSM11301446
# 4  0QFmz/+rJy1Q56C1DuYqT9hKKqi5TUqx0sN0IwvoHrw=             愛投羅網  TWA471306001

# %%
member_reorder_train = member_data.set_index('msno').reindex(train_data['msno'], columns=['city', 'bd', 'gender', 'registered_via', 'registration_init_time', 'expiration_date'], copy = True).set_index(train_data.index)
song_reorder_train = song_data.set_index('song_id').reindex(train_data['song_id'], columns=['song_length', 'genre_ids', 'artist_name', 'composer', 'lyricist', 'language'], copy = True).set_index(train_data.index)
song_extra_reorder_train = song_extra_data.set_index('song_id').reindex(train_data['song_id'], columns=['name', 'isrc'], copy = True).set_index(train_data.index)

# %%
member_reorder_test = member_data.set_index('msno').reindex(test_data['msno'], columns=['city', 'bd', 'gender', 'registered_via', 'registration_init_time', 'expiration_date'], copy = True).set_index(test_data.index)
song_reorder_test = song_data.set_index('song_id').reindex(test_data['song_id'], columns=['song_length', 'genre_ids', 'artist_name', 'composer', 'lyricist', 'language'], copy = True).set_index(test_data.index)
song_extra_reorder_test = song_extra_data.set_index('song_id').reindex(test_data['song_id'], columns=['name', 'isrc'], copy = True).set_index(test_data.index)

# %%
all_train_data = pd.concat([train_data, member_reorder_train, song_reorder_train, song_extra_reorder_train], join='inner', axis=1, copy=True)
all_test_data = pd.concat([test_data, member_reorder_test, song_reorder_test, song_extra_reorder_test], join='inner', axis=1, copy=True)

# %%
all_train_data.to_csv(DATASET_PATH + 'all_train_withextra.csv', index=False)
all_test_data.to_csv(DATASET_PATH + 'all_test_withextra.csv', index=False)

# %%
composer_df = split_and_strip_append(song_data, 'composer', 5, DATASET_PATH + 'all_composer.csv')
print('all_composer saved.')
# Out:
# all_composer saved.

# %%
artist_name_df = split_and_strip_append(song_data, 'artist_name', 4, DATASET_PATH + 'all_artist_name.csv')
print('all_artist_name saved.')
# Out:
# all_artist_name saved.

# %%
lyricist_df = split_and_strip_append(song_data, 'lyricist', 6, DATASET_PATH + 'all_lyricist.csv')
print('all_lyricist saved.')
# Out:
# all_lyricist saved.

# %%
print(train_data.index)
# Out:
# RangeIndex(start=0, stop=7377418, step=1)

# %%
print(member_data.head())
# Out:
#                                            msno  city  bd gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0    NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0    NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0    NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0    NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0    NaN
#
#    registered_via  registration_init_time  expiration_date
# 0               7                20110820         20170920
# 1               7                20150628         20170622
# 2               4                20160411         20170712
# 3               9                20150906         20150907
# 4               4                20170126         20170613

# %%
print(all_train_data.head())
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target  city  bd  gender  \
# 0              Explore  online-playlist       1     1   0     NaN
# 1  Local playlist more   local-playlist       1    13  24  female
# 2  Local playlist more   local-playlist       1    13  24  female
# 3  Local playlist more   local-playlist       1    13  24  female
# 4              Explore  online-playlist       1     1   0     NaN
#
#    registered_via  registration_init_time  expiration_date song_length  \
# 0               7                20120102         20171005      206471
# 1               9                20110525         20170911      284584
# 2               9                20110525         20170911      225396
# 3               9                20110525         20170911      255512
# 4               7                20120102         20171005      187802
#
#   genre_ids      artist_name                                 composer  \
# 0       359         Bastille                     Dan Smith| Mark Crew
# 1      1259  Various Artists                                      NaN
# 2      1259              Nas     N. Jones、W. Adams、J. Lordan、D. Ingle
# 3      1019         Soundway                            Kwadwo Donkoh
# 4      1011      Brett Young  Brett Young| Kelly Archer| Justin Ebach
#
#   lyricist language                                     name          isrc
# 0      NaN       52                               Good Grief  GBUM71602854
# 1      NaN       52                       Lords of Cardboard  US3C69910183
# 2      NaN       52  Hip Hop Is Dead(Album Version (Edited))  USUM70618761
# 3      NaN       -1                             Disco Africa  GBUQH1000063
# 4      NaN       52                        Sleep Without You  QM3E21606003

# %%
print(all_test_data.head())
# Out:
#    id                                          msno  \
# 0   0  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 1   1  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 2   2  /uQAlrAkaczV+nWCd2sPF2ekvXPRipV7q0l+gbLuxjw=
# 3   3  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
# 4   4  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
#
#                                         song_id source_system_tab  \
# 0  WmHKgKMlp1lQMecNdNvDMkvIycZYHnFwDT72I5sIssc=        my library
# 1  y/rsZ9DC7FwK5F2PK2D5mj+aOBUJAjuu3dZ14NgE0vM=        my library
# 2  8eZLFOdGVdXBSqoAv5nsLigeH2BvKXzTQYtUM53I0k4=          discover
# 3  ztCf8thYsS4YN3GcIL/bvoxLm/T5mYBVKOO4C9NiVfQ=             radio
# 4  MKVMpslKcQhMaFEgcEQhEfi5+RZhMYlU3eRDpySrH8Y=             radio
#
#     source_screen_name          source_type  city  bd gender  registered_via  \
# 0  Local playlist more        local-library     1   0    NaN               7
# 1  Local playlist more        local-library     1   0    NaN               7
# 2                  NaN  song-based-playlist     1   0    NaN               4
# 3                Radio                radio     3  30   male               9
# 4                Radio                radio     3  30   male               9
#
#    registration_init_time  expiration_date song_length genre_ids  \
# 0                20160219         20170918      224130       458
# 1                20160219         20170918      320470       465
# 2                20161117         20161124      315899      2022
# 3                20070725         20170430      285210       465
# 4                20070725         20170430      197590       873
#
#           artist_name                                   composer  \
# 0  梁文音 (Rachel Liang)                             Qi Zheng Zhang
# 1        林俊傑 (JJ Lin)                                        林俊傑
# 2  Yu Takahashi (高橋優)                               Yu Takahashi
# 3                  U2  The Edge| Adam Clayton| Larry Mullen| Jr.
# 4       Yoga Mr Sound                                Neuromancer
#
#        lyricist language                                  name          isrc
# 0           NaN        3                                愛其實很殘忍  TWUM71400047
# 1       孫燕姿/易家揚        3                                    她說  TWB671005201
# 2  Yu Takahashi       17                   subarashiki nichijo  JPWP01070260
# 3           NaN       52  Hold Me| Thrill Me| Kiss Me| Kill Me  GBAAN0201228
# 4           NaN       -1                               Om Yoga  ITO101121898

# %%
print(all_train_data)
# Out:
#                                                  msno  \
# 0        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 5        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 6        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 7        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 8        uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 9        uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 10       uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 11       uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 12       TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 13       3g0bC24RD7QUeALY1IF/e8L6X3fHG298ZFIsCEG9T9Y=
# 14       TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 15       3g0bC24RD7QUeALY1IF/e8L6X3fHG298ZFIsCEG9T9Y=
# 16       TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 17       TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 18       TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 19       uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 20       uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 7377414  z1mqaU9YOX7T/PFDvUoWozdFq7rC3KwaQP7nFVprjMI=            search
# 7377415  750RprmFfLV0bymtDH88g24pLZGVi5VpBAI300P6UOA=            search
# 7377416  G8wgqObgeAMER/rVCIlgcNeQ8mm0CzF/GsxiMK8TTnA=          discover
# 7377417  Ju0VGkjWeBUZCd7r5Az2hUImhMoWxWLUicOedsmvG0g=          discover
#
#            source_screen_name          source_type  target  city  bd  gender  \
# 0                     Explore      online-playlist       1     1   0     NaN
# 1         Local playlist more       local-playlist       1    13  24  female
# 2         Local playlist more       local-playlist       1    13  24  female
# 3         Local playlist more       local-playlist       1    13  24  female
# 4                     Explore      online-playlist       1     1   0     NaN
# 5                     Explore      online-playlist       1     1   0     NaN
# 6         Local playlist more       local-playlist       1    13  24  female
# 7                     Explore      online-playlist       1     1   0     NaN
# 8         Local playlist more        local-library       1    15  26    male
# 9         Local playlist more        local-library       1    15  26    male
# 10        Local playlist more        local-library       1    15  26    male
# 11        Local playlist more        local-library       1    15  26    male
# 12                        NaN  top-hits-for-artist       0     1   0     NaN
# 13        Local playlist more        local-library       1     5   0     NaN
# 14        Local playlist more       local-playlist       1     1   0     NaN
# 15        Local playlist more        local-library       1     5   0     NaN
# 16                 My library       local-playlist       1     1   0     NaN
# 17                 My library       local-playlist       1     1   0     NaN
# 18                        NaN  top-hits-for-artist       0     1   0     NaN
# 19        Local playlist more        local-library       1     9  27  female
# 20        Local playlist more        local-library       1     9  27  female
# 21        Local playlist more        local-library       1     9  27  female
# 22        Local playlist more        local-library       1     9  27  female
# 23       Online playlist more      online-playlist       1    15  18    male
# 24       Online playlist more      online-playlist       0    15  18    male
# 25       Online playlist more      online-playlist       0    15  18    male
# 26       Online playlist more      online-playlist       0    15  18    male
# 27        Local playlist more        local-library       1     1   0     NaN
# 28        Local playlist more        local-library       1     1   0     NaN
# 29        Local playlist more        local-library       1    13  34    male
# ...                       ...                  ...     ...   ...  ..     ...
# 7377388   Local playlist more        local-library       0    15  27    male
# 7377389   Local playlist more        local-library       0    15  27    male
# 7377390   Local playlist more       local-playlist       0    15  21  female
# 7377391   Local playlist more        local-library       0    13  41    male
# 7377392            Album more                album       0     6  23    male
# 7377393            Album more                album       0     6  23    male
# 7377394   Local playlist more        local-library       0    15  22    male
# 7377395   Local playlist more        local-library       0    15  22    male
# 7377396   Local playlist more        local-library       0    15  22    male
# 7377397   Local playlist more        local-library       1    13  18    male
# 7377398   Local playlist more       local-playlist       0    15  27    male
# 7377399   Local playlist more       local-playlist       0    15  27    male
# 7377400   Local playlist more       local-playlist       0    15  27    male
# 7377401   Local playlist more       local-playlist       0    22  29  female
# 7377402                   NaN  song-based-playlist       0    22  37  female
# 7377403                   NaN  song-based-playlist       1    22  37  female
# 7377404                   NaN  song-based-playlist       0    22  37  female
# 7377405   Local playlist more        local-library       1     4  28  female
# 7377406  Online playlist more      online-playlist       0     1   0     NaN
# 7377407   Local playlist more        local-library       1     1   0     NaN
# 7377408                Search                 song       0     1   0     NaN
# 7377409                Search                 song       0     1   0     NaN
# 7377410   Local playlist more        local-library       1     1   0     NaN
# 7377411   Local playlist more        local-library       1     1   0     NaN
# 7377412   Local playlist more        local-library       1     1   0     NaN
# 7377413   Local playlist more       local-playlist       1     4  26  female
# 7377414                Search                 song       0     1   0     NaN
# 7377415                Search                 song       1     1   0     NaN
# 7377416        Discover Genre      online-playlist       1     5   0     NaN
# 7377417        Discover Genre      online-playlist       1     5   0     NaN
#
#          registered_via  registration_init_time  expiration_date song_length  \
# 0                     7                20120102         20171005      206471
# 1                     9                20110525         20170911      284584
# 2                     9                20110525         20170911      225396
# 3                     9                20110525         20170911      255512
# 4                     7                20120102         20171005      187802
# 5                     7                20120102         20171005      247803
# 6                     9                20110525         20170911      229982
# 7                     7                20120102         20171005      181115
# 8                     9                20111107         20180304      278964
# 9                     9                20111107         20180304      257369
# 10                    9                20111107         20180304      223933
# 11                    9                20111107         20180304      224597
# 12                    9                20150806         20170930      280084
# 13                    9                20110221         20170922      253492
# 14                    9                20150806         20170930      210364
# 15                    9                20110221         20170922      240624
# 16                    9                20150806         20170930      248790
# 17                    9                20150806         20170930      259877
# 18                    9                20150806         20170930      265743
# 19                    9                20130912         20170912      241975
# 20                    9                20130912         20170912      189846
# 21                    9                20130912         20170912      247911
# 22                    9                20130912         20170912      257671
# 23                    4                20151220         20170930      183251
# 24                    4                20151220         20170930      292060
# 25                    4                20151220         20170930      131239
# 26                    4                20151220         20170930      307200
# 27                    7                20101205         20180104      213902
# 28                    7                20101205         20180104      271255
# 29                    9                20100812         20170912      248581
# ...                 ...                     ...              ...         ...
# 7377388               9                20141224         20170903      275435
# 7377389               9                20141224         20170903      251712
# 7377390               3                20121226         20171006      302688
# 7377391               7                20160115         20170914      268434
# 7377392               9                20081129         20171001      291840
# 7377393               9                20081129         20171001      248999
# 7377394               9                20110306         20170912      225216
# 7377395               9                20110306         20170912      222249
# 7377396               9                20110306         20170912      306549
# 7377397               9                20140817         20170909      208375
# 7377398               9                20050703         20171031      209397
# 7377399               9                20050703         20171031      228101
# 7377400               9                20050703         20171031      311588
# 7377401               3                20130427         20171003      234289
# 7377402               9                20060302         20170930      166217
# 7377403               9                20060302         20170930      224862
# 7377404               9                20060302         20170930      185016
# 7377405               9                20110316         20170930      204521
# 7377406               7                20140112         20170930      198008
# 7377407               7                20131204         20170908      235206
# 7377408               7                20101014         20171003      175449
# 7377409               7                20101014         20171003      163375
# 7377410               7                20170105         20171005      173685
# 7377411               7                20170105         20171005      214459
# 7377412               7                20170105         20171005      229784
# 7377413               9                20041218         20170930      267958
# 7377414               7                20130627         20171006      227404
# 7377415               7                20130627         20171006      258298
# 7377416               9                20150213         20170918      524146
# 7377417               9                20150213         20170918      254026
#
#         genre_ids                                   artist_name  \
# 0             359                                      Bastille
# 1            1259                               Various Artists
# 2            1259                                           Nas
# 3            1019                                      Soundway
# 4            1011                                   Brett Young
# 5            1259                                     Desiigner
# 6             465                               BIGBANG TAEYANG
# 7            1011                                  Thomas Rhett
# 8            2022                                   OneRepublic
# 9             465                                   OneRepublic
# 10            465                              Lindsey Stirling
# 11            465                                    嚴爵 (Yen-j)
# 12            465                                  林俊傑 (JJ Lin)
# 13            458                                周杰倫 (Jay Chou)
# 14        465|458                                  林俊傑 (JJ Lin)
# 15            465                               Various Artists
# 16            465                                 吳汶芳 (Fang Wu)
# 17            458                                    aMEI (張惠妹)
# 18            465                                  林俊傑 (JJ Lin)
# 19            465                               孫燕姿 (Yanzi Sun)
# 20            458                              陳星翰 (Starr Chen)
# 21            465                               莫文蔚 (Karen Mok)
# 22            465                                  五月天 (Mayday)
# 23           2022                                   John Lennon
# 24           2022                                   John Lennon
# 25           2022                                   The Beatles
# 26            465  Pleasantville -Music From The Motion Picture
# 27            465                                 Justin Bieber
# 28            465                                         S.H.E
# 29            NaN                             韋禮安 (William Wei)
# ...           ...                                           ...
# 7377388       451                               許茹芸 (Valen Hsu)
# 7377389       458                                 孫盛希 (Shi Shi)
# 7377390       458                                      Eric 周興哲
# 7377391       458                          動力火車 (Power Station)
# 7377392       465                                           王識賢
# 7377393       465                                           王識賢
# 7377394       465                               Various Artists
# 7377395       458                                 聽見下雨的聲音 電影原聲帶
# 7377396       465                               蘇打綠 (Sodagreen)
# 7377397       465                               孫燕姿 (Yanzi Sun)
# 7377398       465                                    aMEI (張惠妹)
# 7377399       465                                    aMEI (張惠妹)
# 7377400       465                                    aMEI (張惠妹)
# 7377401       465                                           張震嶽
# 7377402      1609                                   MAJOR LAZER
# 7377403      1609                                    Kesha|Zedd
# 7377404      1609                                        Baauer
# 7377405       359                               Various Artists
# 7377406       786                                        寶寶水晶音樂
# 7377407       458                                          AMIT
# 7377408       921                               Various Artists
# 7377409       921                               Various Artists
# 7377410       465                                      Maroon 5
# 7377411       465                                      Maroon 5
# 7377412       465                                      Maroon 5
# 7377413      1259                                       Dr. Dre
# 7377414       465                    R. City feat.  Adam Levine
# 7377415       465                兄弟本色G.U.T.S. (姚中仁、張震嶽、頑童MJ116)
# 7377416      2122                             Brad Mehldau Trio
# 7377417       212                   Biréli Lagrène| Sylvain Luc
#
#                                                   composer  \
# 0                                     Dan Smith| Mark Crew
# 1                                                      NaN
# 2                     N. Jones、W. Adams、J. Lordan、D. Ingle
# 3                                            Kwadwo Donkoh
# 4                  Brett Young| Kelly Archer| Justin Ebach
# 5                                 Sidney Selby| Adnan Khan
# 6                            TEDDY| DEE.P| Rebecca Johnson
# 7                   Thomas Rhett| Rhett Akins| Ben Hayslip
# 8                                              Ryan Tedder
# 9                                              Ryan Tedder
# 10                   Lindsey Stirling| Dia Frampton| SILAS
# 11                                                      嚴爵
# 12                                                     林俊傑
# 13                                                     周杰倫
# 14                                                  JJ Lin
# 15                                                   GAEMI
# 16                                                     吳汶芳
# 17                                               Wang Feng
# 18                                                  JJ Lin
# 19                                             Li Wei Song
# 20                                              Starr Chen
# 21                                             Skot Suyama
# 22                                                     NaN
# 23                                             John Lennon
# 24                             John Lennon| Paul McCartney
# 25                             John Lennon| Paul McCartney
# 26                                                     NaN
# 27       Justin Bieber| Terius Nash| Christopher Stewar...
# 28                                                     周杰倫
# 29                                                     韋禮安
# ...                                                    ...
# 7377388                                      Zhong Ping Ji
# 7377389                                                孫盛希
# 7377390                                          Eric Chou
# 7377391                                               張簡君偉
# 7377392                                                NaN
# 7377393                                                NaN
# 7377394                                 Han Seung Taek/ROZ
# 7377395                                                許叔男
# 7377396                                                NaN
# 7377397                                        Lin Yi Feng
# 7377398                                                阿弟仔
# 7377399                                                梁思樺
# 7377400                                                丹戈爾
# 7377401                                                張震嶽
# 7377402                                                NaN
# 7377403         Anton Zaslavski| Antonina Armato| T. Price
# 7377404                                                NaN
# 7377405  Noah Feldshuh| Casey Harris| Sam Harris| A. Gr...
# 7377406                                                NaN
# 7377407                                          Ai Li Shi
# 7377408                                 Lin-Manuel Miranda
# 7377409                                 Lin-Manuel Miranda
# 7377410                         J. Carmichael| Adam Levine
# 7377411  Kendrick Lamar| Benny Blanco| Adam Levine| Jac...
# 7377412  Ryan Tedder| Noel Zancanella| Adam Levine| Nat...
# 7377413  Andre R. Young| Melvin Charles Bradford| Shawn...
# 7377414  Theron Thomas| Timothy Thomas| Lukasz Gottwald...
# 7377415               姚中仁 MC HotDog 陳昱榕 Ｅ-SO 周文傑 KENZY 林睦淵
# 7377416                                                NaN
# 7377417                  Robert Andrew Hyman| Cyndy Lauper
#
#                                                   lyricist language  \
# 0                                                      NaN       52
# 1                                                      NaN       52
# 2                                                      NaN       52
# 3                                                      NaN       -1
# 4                                                      NaN       52
# 5                                                      NaN       52
# 6                                           TEDDY| TAEYANG       31
# 7                                                      NaN       52
# 8                                                      NaN       52
# 9                                                      NaN       52
# 10                                                     NaN       52
# 11                                                      嚴爵        3
# 12                                                     林怡鳳        3
# 13                                                     周杰倫        3
# 14                                             Lin Yi Feng        3
# 15                               Ji Hoon/Roco of Rocoberry       31
# 16                                                     吳汶芳        3
# 17                                                     NaN        3
# 18                                             Wang Ya Jun        3
# 19                                                Xiao Han        3
# 20                                                     NaN        3
# 21                                                     李焯雄        3
# 22                                                     NaN        3
# 23                                                     NaN       52
# 24                                                     NaN       52
# 25                                                     NaN       52
# 26                                                     NaN       52
# 27                                                     NaN       52
# 28                                               Selina+李姚        3
# 29                                                     韋禮安        3
# ...                                                    ...      ...
# 7377388                                                NaN        3
# 7377389                    蘇三毛\Molly Lin (妮可醬)@i-One Music        3
# 7377390                                        Xue-Man Rao        3
# 7377391                                                藍小邪        3
# 7377392                                                NaN       10
# 7377393                                                NaN       10
# 7377394                                                NaN       31
# 7377395                                                徐若瑄        3
# 7377396                                                NaN        3
# 7377397                                        Yi Jia Yang        3
# 7377398                                                阿弟仔        3
# 7377399                                                易家揚        3
# 7377400                                                陳鎮川        3
# 7377401                                                張震嶽        3
# 7377402                                                NaN       52
# 7377403                                                NaN       52
# 7377404                                                NaN       52
# 7377405                                                NaN       52
# 7377406                                                NaN       -1
# 7377407                                                NaN        3
# 7377408                                                NaN       52
# 7377409                                                NaN       52
# 7377410                                                NaN       52
# 7377411                                                NaN       52
# 7377412                                                NaN       52
# 7377413                                                NaN       52
# 7377414  Theron Thomas| Timothy Thomas| Lukasz Gottwald...       52
# 7377415               姚中仁 MC HotDog 陳昱榕 Ｅ-SO 周文傑 KENZY 林睦淵        3
# 7377416                                                NaN       52
# 7377417                  Robert Andrew Hyman| Cyndy Lauper       52
#
#                                             name          isrc
# 0                                     Good Grief  GBUM71602854
# 1                             Lords of Cardboard  US3C69910183
# 2        Hip Hop Is Dead(Album Version (Edited))  USUM70618761
# 3                                   Disco Africa  GBUQH1000063
# 4                              Sleep Without You  QM3E21606003
# 5                                          Panda  USUM71601094
# 6                     眼| 鼻| 口 (Eyes| Nose| Lips)  TWA531400512
# 7                               Star Of The Show  USLXJ1607334
# 8                              Dreaming Out Loud  USUM70759544
# 9                                 Counting Stars  USUM71301306
# 10                                 We Are Giants  QMF921450114
# 11                                  輕輕 (Lightly)  TWK231507907
# 12             手心的薔薇 (Beautiful) feat. G.E.M.鄧紫棋  TWA531480006
# 13                                      給我一首歌的時間  TWK970801502
# 14                                 關鍵詞 (The Key)  TWA531576504
# 15                 You Are My Everything - Gummy           NaN
# 16                孤獨的總和 (Accumulated Loneliness)  TWA211328806
# 17                                           春天裡  TWUM71600101
# 18                               因你而在 (You N Me)  TWA531398014
# 19                                       雨天 (雨天)  TWA530617601
# 20                      EGO-HOLIC戀我癖 (EGO-HOLIC)  TWUM71600076
# 21                                           愛死你  TWA470326002
# 22                                           麥來亂  TWA450586306
# 23                                       Imagine  GBAYE1000769
# 24                           Give Peace A Chance  GBAYE1000933
# 25             You've Got To Hide Your Love Away  GBAYE0601467
# 26                           Across The Universe  USSM19803669
# 27                                          Baby  USUM70919263
# 28                                           安靜了  TWD950806109
# 29                                         Intro  TWA211630901
# ...                                          ...           ...
# 7377388                                      獨角戲  TWA559610006
# 7377389                                    單身≠失戀  TWA451662401
# 7377390                       我愛過你 (I Loved You)  TWA471602011
# 7377391                   不完美心跳 (Lost Heartbeat)  TWD951567104
# 7377392                                    寄袂出的批           NaN
# 7377393                                       手指           NaN
# 7377394                                This Love           NaN
# 7377395                                     來愛我啦  TWL251305212
# 7377396                                  無與倫比的美麗  TWF670700305
# 7377397                           遇見 (Encounter)  TWA530355702
# 7377398                                      飛高高  TWU971402009
# 7377399                                       三月  TWU971402003
# 7377400                                       自虐  TWU971402004
# 7377401                                    跑車與坦克  TWA451396101
# 7377402      Light It Up (feat. Nyla & Fuse ODG)  QMUY41500182
# 7377403                              True Colors  USUM71603628
# 7377404                                   Temple  GB5P51500097
# 7377405                                 Unsteady  USUM71603401
# 7377406                                   Longer           NaN
# 7377407                                     母系社會  TWU971502003
# 7377408                          How Far I'll Go  USWD11677601
# 7377409                          How Far I'll Go  USWD11677855
# 7377410                        Harder To Breathe  USJAY0300079
# 7377411                         Don't Wanna Know  USUM71609975
# 7377412                            Love Somebody  USUM71204774
# 7377413                             Still D.R.E.  USIR19905031
# 7377414                              Locked Away  USRC11501369
# 7377415                                  FLY OUT  TWA451512031
# 7377416                               Wonderwall  USNO10750721
# 7377417                          Time after time  FR14F9900090
#
# [7377418 rows x 20 columns]
