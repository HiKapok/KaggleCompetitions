# %%
# Running %env without any arguments
# lists all environment variables

# The line below sets the environment
# variable CUDA_VISIBLE_DEVICES
# %env CUDA_VISIBLE_DEVICES = 0

import numpy as np
import pandas as pd
import io
import time
from datetime import datetime
import bson                       # this is installed with the pymongo package
import matplotlib.pyplot as plt
from scipy.misc import imread, imsave, imshow
import tensorflow as tf
from tensorflow.python.platform import tf_logging
from tensorflow.contrib import layers
from tensorflow.contrib.training import add_gradients_summaries
from tensorflow.python.ops import math_ops
from tensorflow.python.framework import ops
from tensorflow.python.ops import array_ops
from tensorflow.python.ops import nn_ops
from tensorflow.python.ops import control_flow_ops
from tensorflow.python.training import optimizer as tf_optimizer
from tensorflow.python.ops import variables as tf_variables
import os.path
import tensorflow.contrib.slim as slim
import inception_preprocessing
import logging
from tensorflow.contrib.slim.python.slim.nets import inception

# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
DATASET_PATH = '/media/rs/0E06CD1706CD0127/Kapok/kaggle/'
#PRETRAINED_MODEL_PATH = DATASET_PATH + 'inception-v3/20160828/inception_v3.ckpt'
#PRETRAINED_MODEL_PATH = DATASET_PATH + 'logs_focalloss/inception_v3_model.ckpt-723669'
PRETRAINED_MODEL_PATH = DATASET_PATH + 'inception_hierachy/level1_fine/inception_model.ckpt-96550'
LOG_PATH = DATASET_PATH + 'inception_hierachy/'
LR_FILE_PATH = DATASET_PATH + 'lr_setting/inception_hierachy_lr_setting'
TRAIN_PATH = DATASET_PATH + 'Split/Train/'
#TRAIN_PATH = '/media/rs/FC6CDC6F6CDC25E4/resample_dataset2/'
VAL_PATH = DATASET_PATH + 'Split/Validation/'
TEST_PATH = DATASET_PATH + 'Test/'
CATEGORY_NAME_PATH = DATASET_PATH + 'category_names.csv'
CATEGORY_WEIGHT_PATH = DATASET_PATH + 'catogory_with_weight.csv'

LEVEL1_NUM_LIST = [555, 441, 440, 237, 230, 230, 220, 206, 196, 184, 180, 162, 158, 137, 106, 104, 103, 101, 99, 89, 88, 85, 84, 83, 81, 74, 57, 50, 48, 45, 43, 42, 42, 38, 33, 33, 30, 29, 26, 25, 19, 16, 9, 6, 2, 1, 1, 1, 1]
# following is non-resample
LEVEL1_WEIGHT = [1.817, 1.528, 1.056, 2.174, 1.622, 2.531, 2.663, 1.103, 1.935, 1.937, 2.898, 1.279, 2.923, 1.095, 2.086, 3.0, 2.218, 3.0, 3.0, 2.123, 3.0, 1.038, 3.0, 3.0, 3.0, 3.0, 1.817, 1.448, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 1.955, 3.0, 1.946, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0]

BATCH_SIZE = 128#256

RUN_WHICH = 'level3'
#RUN_WHICH = 'level1'

IMAGE_WIDTH = 180
IMAGE_HEIGHT = 180
NUM_CLASS = 5270
LEVEL1_CLASS = 49
LEVEL2_CLASS = 483
# validation examples num: 2319624
# train examples num: 10051704
# total step: 157057
TOTAL_EXAMPLES = 12371328

NUM_EPOCHES = 12
EPOCHES_OVER = 8

INPUT_THREADS = 12

initial_learning_rate = 0.001#0.0004
stop_learning_rate = 0.0000001
moving_average_decay = 0.96# use large to be more stable?
momentum = 0.9
num_steps_per_epoch = TOTAL_EXAMPLES / BATCH_SIZE + 1

# %%
# get TF logger
log = logging.getLogger('tensorflow')
log.setLevel(logging.DEBUG)

# create formatter and add it to the handlers
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# create file handler which logs even debug messages
fh = logging.FileHandler(DATASET_PATH + 'tensorflow_inception_hierachy_train.log')
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)
log.addHandler(fh)

# %%
def read_learning_rate(cur_step, num_steps_per_epoch):
    def inner_lr_parser(interval_start, interval_end, lr, dict_in, default_lr, use_epoch_percent, num_steps_per_epoch):
        lr = default_lr * lr
        if use_epoch_percent:
            interval_start = num_steps_per_epoch * interval_start
            interval_end = num_steps_per_epoch * interval_end
        interval_start = int(interval_start)
        interval_end = int(interval_end)
        if (interval_start < interval_end) and (lr > 0):
            dict_in[(interval_start, interval_end)] = lr
            
    lr_map = dict()
    default_lr = initial_learning_rate
    stop_lr = stop_learning_rate
    line_index = -1
    use_epoch_percent = True
    if os.path.exists(LR_FILE_PATH):
        with open(LR_FILE_PATH, 'r') as lr_setting_file:
            for _, line in enumerate(lr_setting_file):
                line = line.strip()
                if (line != '') and (not line.startswith('#')):
                    line_index += 1
                    if line_index == 0:
                        default_lr = float(line.split(':')[-1].strip())
                        continue
                    if line_index == 1:
                        stop_lr = float(line.split(':')[-1].strip())
                        continue
                    if line_index == 2:
                        use_epoch_percent = ('EPOCHES_PERCENT' in (line.split(':')[-1].strip()))
                        continue
                    # this is a list desciption
                    if line.startswith('['):
                        line = [float(s.strip()) for s in line[1:-1].strip().split()]
                        step_interval = (line[1] - line[0])/line[-1]
                        lr_interval = (line[3] - line[2])/line[-1]
                        begin = line[0]
                        lr_begin = line[2]
                        for index in range(int(line[-1])):
                            inner_lr_parser(begin, begin+step_interval, lr_begin, lr_map, default_lr, use_epoch_percent, num_steps_per_epoch)
                            begin += step_interval
                            lr_begin += lr_interval
                    else:
                        interval_start, interval_end, lr = [float(s) for s in line.strip().split()]
                        inner_lr_parser(interval_start, interval_end, lr, lr_map, default_lr, use_epoch_percent, num_steps_per_epoch)
    lr_ret = default_lr
#     print(use_epoch_percent)
    for (start, end), lr in lr_map.items():
        if (cur_step >= start) and (cur_step <= end):
            if (lr < lr_ret):
                lr_ret = lr
    if lr_ret < stop_lr: lr_ret = stop_lr      
    return lr_ret
# _ = read_learning_rate(1, num_steps_per_epoch)
# lr = []
# num_epoches_to_show = 10
# num_point = 100
# for i in [i*num_epoches_to_show*num_steps_per_epoch/num_point for i in range(num_point)]:
#     lr.append(read_learning_rate(i, num_steps_per_epoch))
# plt.plot(lr)
# plt.ylabel('learning rate')
# plt.show()

# %%
def preprocess_for_inception(input_image, is_training = True):
    return inception_preprocessing.preprocess_image(input_image, 160, 160, is_training)

# %%
class LabelMapping(object):
    def __init__(self, catogory_file_path):
        super(LabelMapping, self).__init__()
        self._category_level_csv = catogory_file_path
        self._category_map, self._category_level1_map, self._category_level2_map, self._len_level1, self._len_level2 = self.cvt_csv2tfrecord()
        
        assert (LEVEL1_CLASS == self._len_level1) and (LEVEL2_CLASS == self._len_level2), 'Other two levels are not mapped correctly.'
        self._catogory_weight_map = self.cvt_catogory_weight()
        self._mapping_strings = tf.constant( [ str(key) for key in self._category_map.keys() ] )
        #print(list(self._category_map.keys())[0])
        self._mapping_table = tf.contrib.lookup.index_table_from_tensor(mapping=self._mapping_strings, default_value=0) 
        
        self._level1_table = tf.contrib.lookup.HashTable(tf.contrib.lookup.KeyValueTensorInitializer(list(self._category_level1_map.keys()), list(self._category_level1_map.values()), tf.int64, tf.int64), 0)
        self._level2_table = tf.contrib.lookup.HashTable(tf.contrib.lookup.KeyValueTensorInitializer(list(self._category_level2_map.keys()), list(self._category_level2_map.values()), tf.int64, tf.int64), 0)
        self._weight_table = tf.contrib.lookup.HashTable(tf.contrib.lookup.KeyValueTensorInitializer(list(self._catogory_weight_map.keys()), list(self._catogory_weight_map.values()), tf.int64, tf.float32), 0)

    @property
    def category_map(self):
        return self._category_map
    @property
    def level1_table(self):
        return self._level1_table
    @property
    def level2_table(self):
        return self._level2_table
    @property
    def len_level1(self):
        return self._len_level1
    @property
    def len_level2(self):
        return self._len_level2
    @property
    def mapping_table(self):
        return self._mapping_table
    @property
    def weight_table(self):
        return self._weight_table
    
    def cvt_catogory_weight(self):
        category_weight_map = dict()
        csv = pd.read_csv(CATEGORY_WEIGHT_PATH).values
        for row in csv:  
            category_id, weight = row[0], row[2]
#             if weight > 1.5:
#                 weight = 1.5
            category_weight_map[int(category_id)] = 1.

        return category_weight_map

    def cvt_csv2tfrecord(self):
        level1_map, level2_map = self.create_level_map()
        count = 0
        category_map = dict()
        category_level1_map = dict()
        category_level2_map = dict()
        csv = pd.read_csv(self._category_level_csv).values
        for row in csv:  
            category_id, level1, level2 = row[0], row[1], row[2]
            category_map[category_id] = count
            category_level1_map[int(category_id)] = level1_map[level1]
            category_level2_map[int(category_id)] = level2_map[level2]
            count += 1

        return category_map, category_level1_map, category_level2_map, len(level1_map), len(level2_map)

    def create_level_map(self):
        csv = pd.read_csv(self._category_level_csv).values
        level_list = [list(), list()]
        for row in csv: 
            for level in range(1,3):
                if row[level] not in level_list[level-1]:
                    level_list[level-1].append(row[level])
        return dict(zip(level_list[0], range(len(level_list[0])))), dict(zip(level_list[1], range(len(level_list[1]))))

# %%
class CdiscountDataset(object):
    def __init__(self, data_path, file_begin_match, label_mapping, num_examples, num_classes, buffer_size, batch_size, num_epochs, is_training):
        super(CdiscountDataset, self).__init__()
        #self._data_file_list = [ os.path.join(data_path, x) for x in os.listdir(data_path) if lambda x: os.path.isfile(x) and x.startswith(file_begin_match) ]
        self._data_file_list = data_path + file_begin_match + '*'
        self._num_examples = num_examples
        self._num_classes = num_classes
        self._batch_size = batch_size
        self._buffer_size = buffer_size
        self._num_epochs = num_epochs
        self._is_training = is_training
        self._category_map = label_mapping.category_map
        self._level1_table = label_mapping.level1_table
        self._level2_table = label_mapping.level2_table
        self._len_level1 = label_mapping.len_level1
        self._len_level2 = label_mapping.len_level2
        self._mapping_table = label_mapping.mapping_table
        self._weight_table = label_mapping.weight_table
    
    
    def create_dataset(self):
        opts = tf.python_io.TFRecordOptions(tf.python_io.TFRecordCompressionType.ZLIB)
        reader = lambda : tf.TFRecordReader(options=opts)
        keys_to_features = {
            'img_raw': tf.FixedLenFeature([], tf.string, default_value=''),
            'product_id': tf.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64)),
            # notice that we don't have this feature in our TFRecord, so always default provided
            'format': tf.FixedLenFeature([], tf.string, default_value='jpg'),
            'category_id': tf.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
        }

        items_to_handlers = {
            # automated decode image from features in FixedLenFeature
            'image': slim.tfexample_decoder.Image(image_key='img_raw', format_key='format'),
            'label': slim.tfexample_decoder.Tensor('category_id'),
        }

        decoder = slim.tfexample_decoder.TFExampleDecoder(keys_to_features, items_to_handlers)
        
        self._dataset = slim.dataset.Dataset(
            data_sources = self._data_file_list,
            decoder = decoder,
            reader = reader,
            # num_readers = 8,
            num_samples = self._num_examples,
            #num_classes = self._num_classes,
            items_to_descriptions = None)
        
        # notice that DatasetDataProvider can automate shuffle the examples by ParallelReader using its RandomShuffleQueue
        self._data_provider = slim.dataset_data_provider.DatasetDataProvider(
            self._dataset,
            num_readers = INPUT_THREADS,
            shuffle = True, # default is True
            num_epochs = self._num_epochs,
            common_queue_capacity = self._buffer_size + 4 * self._batch_size,
            common_queue_min = self._buffer_size,
            scope = self._is_training and 'train_files' or 'validation_files')
        
        org_image, org_label = self._data_provider.get(['image', 'label'])

        image = preprocess_for_inception(org_image, self._is_training) # final image to train
 
        # no need for shuffle, DatasetDataProvider do this for us
        batch_images, batch_labels, batch_labels_level1, batch_labels_level2, batch_weight = \
                tf.train.batch([image, tf.one_hot(self._mapping_table.lookup(tf.as_string(org_label)), self._num_classes, axis=-1),\
                tf.one_hot(self._level1_table.lookup(org_label), self._len_level1, axis=-1),\
                tf.one_hot(self._level2_table.lookup(org_label), self._len_level2, axis=-1), self._weight_table.lookup(org_label)],\
                self._batch_size,\
                num_threads = INPUT_THREADS,\
                capacity = self._buffer_size + 4 * self._batch_size,\
                allow_smaller_final_batch = self._is_training, name = self._is_training and 'train_batch' or 'validation_batch')
        
        return batch_images, batch_labels, batch_labels_level1, batch_labels_level2, batch_weight

# %% [markdown]
# 变量，正则，梯度stop

# %%
def_graph = tf.Graph()
with def_graph.as_default() as graph:
    def train_step(input_examples, batch_labels, level1_onehot_labels, level2_onehot_labels, batch_weight):   
        with tf.name_scope("InceptionHierachy"):
            with slim.arg_scope(inception.inception_v3_arg_scope()):
                # here logits is the pre-softmax activations
                logits, end_points = inception.inception_v3(
                    input_examples,
                    num_classes = NUM_CLASS,
                    is_training = True)

                
                #pre_logits = end_points['PreLogits']
                pre_logits = tf.stop_gradient(end_points['PreLogits'])
                #level3_logits = tf.stop_gradient(logits)
                level3_logits = logits
                
                level1_branch = layers.conv2d(pre_logits, 512, [1, 1], scope='level1_branch')
                level1_logits = layers.conv2d(level1_branch, LEVEL1_CLASS, [1, 1], activation_fn=None, normalizer_fn=None, scope='level1_logits')
                level1_prob = tf.nn.softmax(level1_logits, name='level1_prob')

                tvars = tf.trainable_variables()

                level1_vars = [var for var in tvars if 'Conv2d_1c_1x1' not in var.name]
                org_vars = [var for var in tvars if 'level1_' not in var.name]
                org_only_vars = [var for var in tvars if 'Conv2d_1c_1x1' in var.name]
                level1_only_vars = [var for var in tvars if 'level1_' in var.name]
                
                
                #                 variable_averages = tf.train.ExponentialMovingAverage(moving_average_decay)
#                 variables_to_restore_ = variable_averages.variables_to_restore()
#                 variables_to_restore={}
#                 for k,v in variables_to_restore_.items():
#                     if 'InceptionHierarchy/' in k:
#                         k = k.replace('InceptionHierarchy/', '')
#                     variables_to_restore[k] = v
                #print(variables_to_restore)
                variables_to_restore = slim.get_variables_to_restore()
                #print(variables_to_restore)
    
                global_step = tf.train.get_or_create_global_step(graph = graph)
                
            
                loss_level3 = tf.losses.softmax_cross_entropy(onehot_labels = batch_labels, logits = level3_logits, label_smoothing = 0.)
                loss_level1 = tf.losses.softmax_cross_entropy(onehot_labels = level1_onehot_labels, logits = tf.squeeze(level1_logits), label_smoothing = 0.)
                #aux_loss = tf.losses.softmax_cross_entropy(onehot_labels = one_hot_labels, logits = end_points['AuxLogits'], weights=0.2)
                total_loss = tf.losses.get_total_loss(add_regularization_losses=True)    # obtain the regularization losses as well

                custom_learning_rate = tf.placeholder(tf.float32, shape=[])
                #Now we can define the optimizer that takes on the learning rate
                #optimizer = tf.train.AdamOptimizer(learning_rate = custom_learning_rate)
                optimizer = tf.train.MomentumOptimizer(learning_rate = custom_learning_rate, momentum=momentum)

                moving_average_variables = slim.get_model_variables()
                variable_averages = tf.train.ExponentialMovingAverage(moving_average_decay, global_step)
                # Use an alternative set of update ops in addition to the default updates:
                tf.add_to_collection(tf.GraphKeys.UPDATE_OPS, variable_averages.apply(moving_average_variables))


                #train_op_level3 = slim.learning.create_train_op(total_loss, optimizer, summarize_gradients=False, variables_to_train=org_vars)#, clip_gradient_norm=10)
                #train_op_level1 = slim.learning.create_train_op(total_loss, optimizer, summarize_gradients=False, variables_to_train=level1_only_vars)#, clip_gradient_norm=10)
                train_op_level3 = slim.learning.create_train_op(total_loss, optimizer, summarize_gradients=False, variables_to_train=org_only_vars)#, clip_gradient_norm=10)

                if RUN_WHICH == 'level3':
                    train_op = train_op_level3
                else:
                    train_op = train_op_level1
                variables_to_restore_checkpoint = slim.get_variables_to_restore()

                #State the metrics that you want to predict. We get a predictions that is not one_hot_encoded.
                if RUN_WHICH == 'level3':
                    probabilities = end_points['Predictions']
                    predictions = tf.argmax(probabilities, 1)
                    target = batch_labels
                else:
                    probabilities = tf.squeeze(level1_prob)
                    predictions = tf.argmax(probabilities, 1)
                    target = level1_onehot_labels
                accuracy, accuracy_update = tf.contrib.metrics.streaming_accuracy(predictions, tf.argmax(target, 1), name='train_accuracy')
                metrics_op = tf.group(accuracy_update)

                real_time_accuracy = tf.reduce_mean(tf.cast(tf.equal(predictions, tf.argmax(target, 1)), tf.float32))
                
                #Now finally create all the summaries you need to monitor and group them into one summary op.
                tf.summary.scalar('losses/Total_Loss', total_loss)
                tf.summary.scalar('accuracy', accuracy)
                tf.summary.scalar('train/real_time_accuracy', real_time_accuracy)
                tf.summary.scalar('learning_rate', custom_learning_rate)

                return train_op, global_step, metrics_op, variables_to_restore, variables_to_restore_checkpoint, predictions, custom_learning_rate, accuracy, real_time_accuracy, total_loss

# %%
with def_graph.as_default() as graph:
    label_mapping = LabelMapping(CATEGORY_NAME_PATH)
    train_dataset = CdiscountDataset(TRAIN_PATH, 'output_file', label_mapping, TOTAL_EXAMPLES, NUM_CLASS, 12000, BATCH_SIZE, NUM_EPOCHES, True)

    batch_images, batch_labels, batch_labels_level1, batch_labels_level2, batch_weight = train_dataset.create_dataset()
   
    with tf.device('/gpu:0'):
        train_op, global_step, metrics_op, variables_to_restore, variables_to_restore_checkpoint, pred_op, lr, accuracy, real_time_accuracy, total_loss = train_step(batch_images, batch_labels, batch_labels_level1, batch_labels_level2, batch_weight)
         
    summary_op = tf.summary.merge_all()

    checkpoint_saver = tf.train.Saver(variables_to_restore_checkpoint)
    
    pre_train_saver = tf.train.Saver(variables_to_restore)

    def load_pretrain(sess):
        pre_train_saver.restore(sess, PRETRAINED_MODEL_PATH)

    # no need for specify local_variables_initializer and tables_initializer, Supervisor will do this via default local_init_op
    # init_op = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer(), tf.tables_initializer())
    init_op = tf.group(tf.global_variables_initializer())
    #init_op = tf.group(train_iterator_initializer, val_iterator_initializer, tf.global_variables_initializer())
    
    # Pass the init function to the supervisor.
    # - The init function is called _after_ the variables have been initialized by running the init_op.
    # - use default tf.Saver() for ordinary save and restore
    # - save checkpoint every 1.3 hours(4800)
    # - manage summary in current process by ourselves for memory saving
    # - no need to specify global_step, supervisor will find this automately
    # - initialize order: checkpoint -> local_init_op -> init_op -> init_func
    sv = tf.train.Supervisor(logdir=LOG_PATH, init_fn = load_pretrain, init_op = init_op, summary_op = None, saver = checkpoint_saver, save_model_secs=7200, checkpoint_basename='inception_model.ckpt')
    
    final_loss = 0.
    final_accuracy = 0.
    training_state = True

    cur_readed_lr = initial_learning_rate
    tf_logging.info(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
    
    config = tf.ConfigProto(log_device_placement=True, allow_soft_placement=True)
    #config.gpu_options.allow_growth = True
    with sv.managed_session(config=config) as sess:
    #with sv.prepare_or_wait_for_session(config=tf.ConfigProto(log_device_placement=True, allow_soft_placement=True)) as sess:
        #sess.run(iterator_initalizer)
        # Here sess was either initialized from the pre-trained-checkpoint or
        # recovered from a checkpoint saved in a previous run of this code.
        for step in range(int(num_steps_per_epoch * NUM_EPOCHES)):         
            if sv.should_stop():
                tf_logging.info('Supervisor emit finished!')
                tf_logging.info('Current Loss: %s', loss)
                tf_logging.info('Current Accuracy: %s', accuracy)
                tf_logging.info('Saving current model to disk(maybe invalid).')
                training_state = False
                break

            start_time = time.time()

            if step % 1000 == 0:
                summ, cur_global_step = sess.run([summary_op, global_step], feed_dict={lr: cur_readed_lr})
                sv.summary_computed(sess, summ)
                if step > EPOCHES_OVER * num_steps_per_epoch:
                    raise StopIteration("over epoches reached.")
                cur_readed_lr = read_learning_rate(cur_global_step, num_steps_per_epoch)

            with tf.device('/gpu:0'):
                _, _, cur_loss, cur_acc, rt_accuracy, total_step, cur_lr = sess.run([train_op, metrics_op, total_loss, accuracy, real_time_accuracy, global_step, lr], feed_dict={lr: cur_readed_lr})
            time_elapsed = time.time() - start_time

            if step % 10 == 0:
                final_loss = cur_loss
                final_accuracy = cur_acc
                tf_logging.info('Current Speed: {:5.3f}sec/batch'.format(time_elapsed))
                tf_logging.info('Current Streaming Accuracy: {:5.3f}%'.format(cur_acc*100.))
                tf_logging.info('Current Realtime Accuracy: {:5.3f}%'.format(rt_accuracy*100.))
                tf_logging.info('Current Loss: {:5.3f}'.format(cur_loss))
                tf_logging.info('Epoch %s/%s, Global Step: %s', int(total_step / num_steps_per_epoch + 1), NUM_EPOCHES, total_step)
                tf_logging.info('Current Learning Rate: {}'.format(cur_lr))

        if training_state:
            #We log the final training loss and accuracy
            tf_logging.info('Final Loss: %s', final_loss)
            tf_logging.info('Final Accuracy: %s', final_accuracy)
            # Once all the training has been done, save the log files and checkpoint model
            tf_logging.info('Finished training! Model saved.')
        sv.saver.save(sess, sv.save_path, global_step = sv.global_step)
        tf_logging.info(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# WARNING:tensorflow:From /home/kapok/pyenv35/lib/python3.5/site-packages/tensorflow/contrib/training/python/training/training.py:412: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# INFO:tensorflow:2017-12-01 09:28:36
# INFO:tensorflow:Restoring parameters from /media/rs/0E06CD1706CD0127/Kapok/kaggle/inception_hierachy/level1_fine/inception_model.ckpt-96550
# INFO:tensorflow:Starting standard services.
# INFO:tensorflow:Saving checkpoint to path /media/rs/0E06CD1706CD0127/Kapok/kaggle/inception_hierachy/inception_model.ckpt
# INFO:tensorflow:Starting queue runners.
# INFO:tensorflow:global_step/sec: 0
# INFO:tensorflow:Current Speed: 8.140sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 0.000%
# INFO:tensorflow:Current Realtime Accuracy: 50.000%
# INFO:tensorflow:Current Loss: 5.388
# INFO:tensorflow:Epoch 1/12, Global Step: 1
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.286sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 45.937%
# INFO:tensorflow:Current Realtime Accuracy: 40.625%
# INFO:tensorflow:Current Loss: 6.457
# INFO:tensorflow:Epoch 1/12, Global Step: 11
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.281sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.688%
# INFO:tensorflow:Current Realtime Accuracy: 48.438%
# INFO:tensorflow:Current Loss: 5.620
# INFO:tensorflow:Epoch 1/12, Global Step: 21
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.283sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.896%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 6.854
# INFO:tensorflow:Epoch 1/12, Global Step: 31
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.284sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.980%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.205
# INFO:tensorflow:Epoch 1/12, Global Step: 41
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.285sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 45.125%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 5.801
# INFO:tensorflow:Epoch 1/12, Global Step: 51
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.281sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.883%
# INFO:tensorflow:Current Realtime Accuracy: 40.625%
# INFO:tensorflow:Current Loss: 5.965
# INFO:tensorflow:Epoch 1/12, Global Step: 61
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.287sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.821%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.640
# INFO:tensorflow:Epoch 1/12, Global Step: 71
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.285sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.521%
# INFO:tensorflow:Current Realtime Accuracy: 36.719%
# INFO:tensorflow:Current Loss: 6.523
# INFO:tensorflow:Epoch 1/12, Global Step: 81
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.286sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.392%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 5.842
# INFO:tensorflow:Epoch 1/12, Global Step: 91
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.275sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.273%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 5.960
# INFO:tensorflow:Epoch 1/12, Global Step: 101
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.296sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.524%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 5.975
# INFO:tensorflow:Epoch 1/12, Global Step: 111
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.274sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.544%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 5.673
# INFO:tensorflow:Epoch 1/12, Global Step: 121
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.285sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.567%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 6.095
# INFO:tensorflow:Epoch 1/12, Global Step: 131
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.290sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.593%
# INFO:tensorflow:Current Realtime Accuracy: 58.594%
# INFO:tensorflow:Current Loss: 4.910
# INFO:tensorflow:Epoch 1/12, Global Step: 141
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.283sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.792%
# INFO:tensorflow:Current Realtime Accuracy: 53.906%
# INFO:tensorflow:Current Loss: 5.865
# INFO:tensorflow:Epoch 1/12, Global Step: 151
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.284sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.810%
# INFO:tensorflow:Current Realtime Accuracy: 51.562%
# INFO:tensorflow:Current Loss: 6.033
# INFO:tensorflow:Epoch 1/12, Global Step: 161
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.294sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.968%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 5.828
# INFO:tensorflow:Epoch 1/12, Global Step: 171
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.284sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 45.117%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 5.620
# INFO:tensorflow:Epoch 1/12, Global Step: 181
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.287sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 45.107%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.781
# INFO:tensorflow:Epoch 1/12, Global Step: 191
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.288sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 45.180%
# INFO:tensorflow:Current Realtime Accuracy: 51.562%
# INFO:tensorflow:Current Loss: 5.313
# INFO:tensorflow:Epoch 1/12, Global Step: 201
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.284sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 45.160%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.871
# INFO:tensorflow:Epoch 1/12, Global Step: 211
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.288sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 45.107%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 5.618
# INFO:tensorflow:Epoch 1/12, Global Step: 221
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.282sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 45.143%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 5.763
# INFO:tensorflow:Epoch 1/12, Global Step: 231
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.289sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 45.000%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 6.274
# INFO:tensorflow:Epoch 1/12, Global Step: 241
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.277sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.919%
# INFO:tensorflow:Current Realtime Accuracy: 39.062%
# INFO:tensorflow:Current Loss: 6.497
# INFO:tensorflow:Epoch 1/12, Global Step: 251
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.284sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.889%
# INFO:tensorflow:Current Realtime Accuracy: 39.844%
# INFO:tensorflow:Current Loss: 5.981
# INFO:tensorflow:Epoch 1/12, Global Step: 261
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.280sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.925%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.254
# INFO:tensorflow:Epoch 1/12, Global Step: 271
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.288sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.916%
# INFO:tensorflow:Current Realtime Accuracy: 42.969%
# INFO:tensorflow:Current Loss: 5.984
# INFO:tensorflow:Epoch 1/12, Global Step: 281
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.282sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.965%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 6.175
# INFO:tensorflow:Epoch 1/12, Global Step: 291
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.295sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.997%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.277
# INFO:tensorflow:Epoch 1/12, Global Step: 301
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.277sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.947%
# INFO:tensorflow:Current Realtime Accuracy: 40.625%
# INFO:tensorflow:Current Loss: 6.247
# INFO:tensorflow:Epoch 1/12, Global Step: 311
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.281sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.902%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 6.192
# INFO:tensorflow:Epoch 1/12, Global Step: 321
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.297sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.886%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.233
# INFO:tensorflow:Epoch 1/12, Global Step: 331
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.280sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.828%
# INFO:tensorflow:Current Realtime Accuracy: 48.438%
# INFO:tensorflow:Current Loss: 5.963
# INFO:tensorflow:Epoch 1/12, Global Step: 341
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.287sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.848%
# INFO:tensorflow:Current Realtime Accuracy: 49.219%
# INFO:tensorflow:Current Loss: 5.745
# INFO:tensorflow:Epoch 1/12, Global Step: 351
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.283sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.816%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 6.159
# INFO:tensorflow:Epoch 1/12, Global Step: 361
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.280sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.694%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 6.297
# INFO:tensorflow:Epoch 1/12, Global Step: 371
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.287sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.616%
# INFO:tensorflow:Current Realtime Accuracy: 42.969%
# INFO:tensorflow:Current Loss: 6.856
# INFO:tensorflow:Epoch 1/12, Global Step: 381
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.285sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.623%
# INFO:tensorflow:Current Realtime Accuracy: 42.969%
# INFO:tensorflow:Current Loss: 5.968
# INFO:tensorflow:Epoch 1/12, Global Step: 391
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:global_step/sec: 3.29165
# INFO:tensorflow:Current Speed: 0.276sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.592%
# INFO:tensorflow:Current Realtime Accuracy: 52.344%
# INFO:tensorflow:Current Loss: 5.604
# INFO:tensorflow:Epoch 1/12, Global Step: 401
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.284sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.609%
# INFO:tensorflow:Current Realtime Accuracy: 33.594%
# INFO:tensorflow:Current Loss: 6.654
# INFO:tensorflow:Epoch 1/12, Global Step: 411
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.291sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.563%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.769
# INFO:tensorflow:Epoch 1/12, Global Step: 421
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.271sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.562%
# INFO:tensorflow:Current Realtime Accuracy: 50.000%
# INFO:tensorflow:Current Loss: 5.734
# INFO:tensorflow:Epoch 1/12, Global Step: 431
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.281sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.590%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 5.958
# INFO:tensorflow:Epoch 1/12, Global Step: 441
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.287sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.550%
# INFO:tensorflow:Current Realtime Accuracy: 40.625%
# INFO:tensorflow:Current Loss: 6.252
# INFO:tensorflow:Epoch 1/12, Global Step: 451
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.275sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.533%
# INFO:tensorflow:Current Realtime Accuracy: 48.438%
# INFO:tensorflow:Current Loss: 6.062
# INFO:tensorflow:Epoch 1/12, Global Step: 461
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.285sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.510%
# INFO:tensorflow:Current Realtime Accuracy: 53.125%
# INFO:tensorflow:Current Loss: 5.447
# INFO:tensorflow:Epoch 1/12, Global Step: 471
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.279sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.500%
# INFO:tensorflow:Current Realtime Accuracy: 49.219%
# INFO:tensorflow:Current Loss: 5.508
# INFO:tensorflow:Epoch 1/12, Global Step: 481
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.286sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.560%
# INFO:tensorflow:Current Realtime Accuracy: 39.844%
# INFO:tensorflow:Current Loss: 6.171
# INFO:tensorflow:Epoch 1/12, Global Step: 491
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.281sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.573%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 6.514
# INFO:tensorflow:Epoch 1/12, Global Step: 501
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.290sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.553%
# INFO:tensorflow:Current Realtime Accuracy: 39.062%
# INFO:tensorflow:Current Loss: 6.074
# INFO:tensorflow:Epoch 1/12, Global Step: 511
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.283sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.509%
# INFO:tensorflow:Current Realtime Accuracy: 42.969%
# INFO:tensorflow:Current Loss: 6.207
# INFO:tensorflow:Epoch 1/12, Global Step: 521
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.275sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.468%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.322
# INFO:tensorflow:Epoch 1/12, Global Step: 531
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.286sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.447%
# INFO:tensorflow:Current Realtime Accuracy: 38.281%
# INFO:tensorflow:Current Loss: 5.967
# INFO:tensorflow:Epoch 1/12, Global Step: 541
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.292sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.420%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 5.819
# INFO:tensorflow:Epoch 1/12, Global Step: 551
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.288sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.392%
# INFO:tensorflow:Current Realtime Accuracy: 39.844%
# INFO:tensorflow:Current Loss: 6.089
# INFO:tensorflow:Epoch 1/12, Global Step: 561
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.285sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.374%
# INFO:tensorflow:Current Realtime Accuracy: 48.438%
# INFO:tensorflow:Current Loss: 5.728
# INFO:tensorflow:Epoch 1/12, Global Step: 571
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.277sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.410%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 5.922
# INFO:tensorflow:Epoch 1/12, Global Step: 581
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.285sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.413%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 5.753
# INFO:tensorflow:Epoch 1/12, Global Step: 591
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.293sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.435%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 5.854
# INFO:tensorflow:Epoch 1/12, Global Step: 601
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.288sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.471%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 5.886
# INFO:tensorflow:Epoch 1/12, Global Step: 611
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.284sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.462%
# INFO:tensorflow:Current Realtime Accuracy: 51.562%
# INFO:tensorflow:Current Loss: 5.478
# INFO:tensorflow:Epoch 1/12, Global Step: 621
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.288sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.470%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 5.804
# INFO:tensorflow:Epoch 1/12, Global Step: 631
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.290sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.501%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 5.891
# INFO:tensorflow:Epoch 1/12, Global Step: 641
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.280sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.526%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 6.231
# INFO:tensorflow:Epoch 1/12, Global Step: 651
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.284sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.560%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 6.072
# INFO:tensorflow:Epoch 1/12, Global Step: 661
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.280sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.559%
# INFO:tensorflow:Current Realtime Accuracy: 51.562%
# INFO:tensorflow:Current Loss: 5.505
# INFO:tensorflow:Epoch 1/12, Global Step: 671
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.277sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.543%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.605
# INFO:tensorflow:Epoch 1/12, Global Step: 681
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.292sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.565%
# INFO:tensorflow:Current Realtime Accuracy: 50.781%
# INFO:tensorflow:Current Loss: 5.170
# INFO:tensorflow:Epoch 1/12, Global Step: 691
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.286sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.605%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.850
# INFO:tensorflow:Epoch 1/12, Global Step: 701
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.277sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.601%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 6.019
# INFO:tensorflow:Epoch 1/12, Global Step: 711
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.279sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.614%
# INFO:tensorflow:Current Realtime Accuracy: 39.844%
# INFO:tensorflow:Current Loss: 6.110
# INFO:tensorflow:Epoch 1/12, Global Step: 721
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.292sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.595%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 5.972
# INFO:tensorflow:Epoch 1/12, Global Step: 731
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.293sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.599%
# INFO:tensorflow:Current Realtime Accuracy: 50.000%
# INFO:tensorflow:Current Loss: 5.297
# INFO:tensorflow:Epoch 1/12, Global Step: 741
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.280sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.597%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.159
# INFO:tensorflow:Epoch 1/12, Global Step: 751
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.277sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.592%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 6.159
# INFO:tensorflow:Epoch 1/12, Global Step: 761
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.286sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.570%
# INFO:tensorflow:Current Realtime Accuracy: 35.938%
# INFO:tensorflow:Current Loss: 6.114
# INFO:tensorflow:Epoch 1/12, Global Step: 771
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.286sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.584%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 6.045
# INFO:tensorflow:Epoch 1/12, Global Step: 781
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.282sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.573%
# INFO:tensorflow:Current Realtime Accuracy: 32.812%
# INFO:tensorflow:Current Loss: 6.712
# INFO:tensorflow:Epoch 1/12, Global Step: 791
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.278sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.547%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 6.017
# INFO:tensorflow:Epoch 1/12, Global Step: 801
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.287sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.538%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 6.405
# INFO:tensorflow:Epoch 1/12, Global Step: 811
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:global_step/sec: 3.525
# INFO:tensorflow:Current Speed: 0.287sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.513%
# INFO:tensorflow:Current Realtime Accuracy: 42.969%
# INFO:tensorflow:Current Loss: 6.383
# INFO:tensorflow:Epoch 1/12, Global Step: 821
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.279sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.480%
# INFO:tensorflow:Current Realtime Accuracy: 36.719%
# INFO:tensorflow:Current Loss: 6.845
# INFO:tensorflow:Epoch 1/12, Global Step: 831
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.289sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.408%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 6.209
# INFO:tensorflow:Epoch 1/12, Global Step: 841
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.290sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.392%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.023
# INFO:tensorflow:Epoch 1/12, Global Step: 851
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.311sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.347%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 6.090
# INFO:tensorflow:Epoch 1/12, Global Step: 861
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.300sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.358%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.967
# INFO:tensorflow:Epoch 1/12, Global Step: 871
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.313sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.356%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 6.345
# INFO:tensorflow:Epoch 1/12, Global Step: 881
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.302sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.374%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 5.904
# INFO:tensorflow:Epoch 1/12, Global Step: 891
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.300sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.386%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 6.265
# INFO:tensorflow:Epoch 1/12, Global Step: 901
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.299sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.368%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 6.115
# INFO:tensorflow:Epoch 1/12, Global Step: 911
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.301sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.379%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 6.443
# INFO:tensorflow:Epoch 1/12, Global Step: 921
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.304sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.374%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.712
# INFO:tensorflow:Epoch 1/12, Global Step: 931
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.314sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.389%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 5.678
# INFO:tensorflow:Epoch 1/12, Global Step: 941
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.324sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.373%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.281
# INFO:tensorflow:Epoch 1/12, Global Step: 951
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.296sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.383%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 5.998
# INFO:tensorflow:Epoch 1/12, Global Step: 961
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.292sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.395%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 6.201
# INFO:tensorflow:Epoch 1/12, Global Step: 971
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.285sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.368%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 5.510
# INFO:tensorflow:Epoch 1/12, Global Step: 981
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.288sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.347%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.288
# INFO:tensorflow:Epoch 1/12, Global Step: 991
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.567sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.340%
# INFO:tensorflow:Current Realtime Accuracy: 50.000%
# INFO:tensorflow:Current Loss: 5.653
# INFO:tensorflow:Epoch 1/12, Global Step: 1001
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.299sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.324%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 6.319
# INFO:tensorflow:Epoch 1/12, Global Step: 1011
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.298sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.337%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 5.674
# INFO:tensorflow:Epoch 1/12, Global Step: 1021
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.296sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.342%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 6.247
# INFO:tensorflow:Epoch 1/12, Global Step: 1031
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.298sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.337%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 6.270
# INFO:tensorflow:Epoch 1/12, Global Step: 1041
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.316sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.320%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 5.870
# INFO:tensorflow:Epoch 1/12, Global Step: 1051
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.292sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.326%
# INFO:tensorflow:Current Realtime Accuracy: 49.219%
# INFO:tensorflow:Current Loss: 5.954
# INFO:tensorflow:Epoch 1/12, Global Step: 1061
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.310sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.329%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.916
# INFO:tensorflow:Epoch 1/12, Global Step: 1071
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.317sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.355%
# INFO:tensorflow:Current Realtime Accuracy: 39.844%
# INFO:tensorflow:Current Loss: 6.555
# INFO:tensorflow:Epoch 1/12, Global Step: 1081
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.293sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.364%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 5.659
# INFO:tensorflow:Epoch 1/12, Global Step: 1091
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.290sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.384%
# INFO:tensorflow:Current Realtime Accuracy: 53.125%
# INFO:tensorflow:Current Loss: 5.616
# INFO:tensorflow:Epoch 1/12, Global Step: 1101
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.304sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.409%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 6.069
# INFO:tensorflow:Epoch 1/12, Global Step: 1111
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.311sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.418%
# INFO:tensorflow:Current Realtime Accuracy: 39.844%
# INFO:tensorflow:Current Loss: 6.449
# INFO:tensorflow:Epoch 1/12, Global Step: 1121
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.302sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.416%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 6.380
# INFO:tensorflow:Epoch 1/12, Global Step: 1131
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.296sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.433%
# INFO:tensorflow:Current Realtime Accuracy: 39.844%
# INFO:tensorflow:Current Loss: 6.235
# INFO:tensorflow:Epoch 1/12, Global Step: 1141
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.296sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.429%
# INFO:tensorflow:Current Realtime Accuracy: 52.344%
# INFO:tensorflow:Current Loss: 5.870
# INFO:tensorflow:Epoch 1/12, Global Step: 1151
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.311sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.432%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.643
# INFO:tensorflow:Epoch 1/12, Global Step: 1161
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.295sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.439%
# INFO:tensorflow:Current Realtime Accuracy: 38.281%
# INFO:tensorflow:Current Loss: 6.471
# INFO:tensorflow:Epoch 1/12, Global Step: 1171
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.302sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.442%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.017
# INFO:tensorflow:Epoch 1/12, Global Step: 1181
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.307sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.448%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.567
# INFO:tensorflow:Epoch 1/12, Global Step: 1191
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.308sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.443%
# INFO:tensorflow:Current Realtime Accuracy: 39.062%
# INFO:tensorflow:Current Loss: 6.204
# INFO:tensorflow:Epoch 1/12, Global Step: 1201
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.292sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.447%
# INFO:tensorflow:Current Realtime Accuracy: 42.969%
# INFO:tensorflow:Current Loss: 6.199
# INFO:tensorflow:Epoch 1/12, Global Step: 1211
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:global_step/sec: 3.30834
# INFO:tensorflow:Current Speed: 0.291sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.442%
# INFO:tensorflow:Current Realtime Accuracy: 37.500%
# INFO:tensorflow:Current Loss: 6.269
# INFO:tensorflow:Epoch 1/12, Global Step: 1221
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.299sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.435%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 5.536
# INFO:tensorflow:Epoch 1/12, Global Step: 1231
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.333sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.439%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.547
# INFO:tensorflow:Epoch 1/12, Global Step: 1241
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.319sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.433%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 5.571
# INFO:tensorflow:Epoch 1/12, Global Step: 1251
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.294sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.430%
# INFO:tensorflow:Current Realtime Accuracy: 38.281%
# INFO:tensorflow:Current Loss: 6.150
# INFO:tensorflow:Epoch 1/12, Global Step: 1261
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.309sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.425%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 5.752
# INFO:tensorflow:Epoch 1/12, Global Step: 1271
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.299sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.407%
# INFO:tensorflow:Current Realtime Accuracy: 37.500%
# INFO:tensorflow:Current Loss: 6.663
# INFO:tensorflow:Epoch 1/12, Global Step: 1281
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.284sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.380%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 5.576
# INFO:tensorflow:Epoch 1/12, Global Step: 1291
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.306sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.379%
# INFO:tensorflow:Current Realtime Accuracy: 42.188%
# INFO:tensorflow:Current Loss: 6.639
# INFO:tensorflow:Epoch 1/12, Global Step: 1301
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.315sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.365%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 6.225
# INFO:tensorflow:Epoch 1/12, Global Step: 1311
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.297sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.360%
# INFO:tensorflow:Current Realtime Accuracy: 35.938%
# INFO:tensorflow:Current Loss: 6.771
# INFO:tensorflow:Epoch 1/12, Global Step: 1321
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.294sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.346%
# INFO:tensorflow:Current Realtime Accuracy: 35.938%
# INFO:tensorflow:Current Loss: 6.512
# INFO:tensorflow:Epoch 1/12, Global Step: 1331
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.322sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.323%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 5.744
# INFO:tensorflow:Epoch 1/12, Global Step: 1341
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.292sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.308%
# INFO:tensorflow:Current Realtime Accuracy: 39.844%
# INFO:tensorflow:Current Loss: 6.298
# INFO:tensorflow:Epoch 1/12, Global Step: 1351
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.299sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.292%
# INFO:tensorflow:Current Realtime Accuracy: 48.438%
# INFO:tensorflow:Current Loss: 6.164
# INFO:tensorflow:Epoch 1/12, Global Step: 1361
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.288sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.304%
# INFO:tensorflow:Current Realtime Accuracy: 35.156%
# INFO:tensorflow:Current Loss: 6.236
# INFO:tensorflow:Epoch 1/12, Global Step: 1371
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.288sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.301%
# INFO:tensorflow:Current Realtime Accuracy: 38.281%
# INFO:tensorflow:Current Loss: 6.271
# INFO:tensorflow:Epoch 1/12, Global Step: 1381
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.296sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.300%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 6.360
# INFO:tensorflow:Epoch 1/12, Global Step: 1391
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.326sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.282%
# INFO:tensorflow:Current Realtime Accuracy: 50.781%
# INFO:tensorflow:Current Loss: 5.328
# INFO:tensorflow:Epoch 1/12, Global Step: 1401
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.299sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.290%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 6.132
# INFO:tensorflow:Epoch 1/12, Global Step: 1411
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.295sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.286%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 5.716
# INFO:tensorflow:Epoch 1/12, Global Step: 1421
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.300sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.295%
# INFO:tensorflow:Current Realtime Accuracy: 48.438%
# INFO:tensorflow:Current Loss: 5.575
# INFO:tensorflow:Epoch 1/12, Global Step: 1431
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.301sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.295%
# INFO:tensorflow:Current Realtime Accuracy: 33.594%
# INFO:tensorflow:Current Loss: 6.567
# INFO:tensorflow:Epoch 1/12, Global Step: 1441
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.295sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.289%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 6.336
# INFO:tensorflow:Epoch 1/12, Global Step: 1451
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.314sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.271%
# INFO:tensorflow:Current Realtime Accuracy: 50.000%
# INFO:tensorflow:Current Loss: 5.785
# INFO:tensorflow:Epoch 1/12, Global Step: 1461
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.304sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.264%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 5.851
# INFO:tensorflow:Epoch 1/12, Global Step: 1471
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.308sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.257%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 6.337
# INFO:tensorflow:Epoch 1/12, Global Step: 1481
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.312sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.271%
# INFO:tensorflow:Current Realtime Accuracy: 38.281%
# INFO:tensorflow:Current Loss: 6.592
# INFO:tensorflow:Epoch 1/12, Global Step: 1491
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.300sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.267%
# INFO:tensorflow:Current Realtime Accuracy: 42.969%
# INFO:tensorflow:Current Loss: 5.497
# INFO:tensorflow:Epoch 1/12, Global Step: 1501
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.307sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.269%
# INFO:tensorflow:Current Realtime Accuracy: 42.969%
# INFO:tensorflow:Current Loss: 6.080
# INFO:tensorflow:Epoch 1/12, Global Step: 1511
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.300sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.271%
# INFO:tensorflow:Current Realtime Accuracy: 51.562%
# INFO:tensorflow:Current Loss: 5.876
# INFO:tensorflow:Epoch 1/12, Global Step: 1521
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.300sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.262%
# INFO:tensorflow:Current Realtime Accuracy: 38.281%
# INFO:tensorflow:Current Loss: 6.626
# INFO:tensorflow:Epoch 1/12, Global Step: 1531
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.318sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.270%
# INFO:tensorflow:Current Realtime Accuracy: 52.344%
# INFO:tensorflow:Current Loss: 5.467
# INFO:tensorflow:Epoch 1/12, Global Step: 1541
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.304sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.271%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 6.361
# INFO:tensorflow:Epoch 1/12, Global Step: 1551
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.301sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.273%
# INFO:tensorflow:Current Realtime Accuracy: 51.562%
# INFO:tensorflow:Current Loss: 5.760
# INFO:tensorflow:Epoch 1/12, Global Step: 1561
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.332sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.283%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 6.252
# INFO:tensorflow:Epoch 1/12, Global Step: 1571
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.312sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.298%
# INFO:tensorflow:Current Realtime Accuracy: 50.000%
# INFO:tensorflow:Current Loss: 5.218
# INFO:tensorflow:Epoch 1/12, Global Step: 1581
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.295sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.306%
# INFO:tensorflow:Current Realtime Accuracy: 42.969%
# INFO:tensorflow:Current Loss: 6.606
# INFO:tensorflow:Epoch 1/12, Global Step: 1591
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.322sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.322%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 5.723
# INFO:tensorflow:Epoch 1/12, Global Step: 1601
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:global_step/sec: 3.275
# INFO:tensorflow:Current Speed: 0.303sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.332%
# INFO:tensorflow:Current Realtime Accuracy: 50.000%
# ...
# INFO:tensorflow:Current Streaming Accuracy: 44.228%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 5.961
# INFO:tensorflow:Epoch 1/12, Global Step: 2071
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.309sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.228%
# INFO:tensorflow:Current Realtime Accuracy: 50.000%
# INFO:tensorflow:Current Loss: 5.947
# INFO:tensorflow:Epoch 1/12, Global Step: 2081
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.301sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.240%
# INFO:tensorflow:Current Realtime Accuracy: 50.000%
# INFO:tensorflow:Current Loss: 5.679
# INFO:tensorflow:Epoch 1/12, Global Step: 2091
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.303sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.253%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.661
# INFO:tensorflow:Epoch 1/12, Global Step: 2101
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.296sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.250%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 5.690
# INFO:tensorflow:Epoch 1/12, Global Step: 2111
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.299sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.254%
# INFO:tensorflow:Current Realtime Accuracy: 40.625%
# INFO:tensorflow:Current Loss: 6.587
# INFO:tensorflow:Epoch 1/12, Global Step: 2121
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.328sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.258%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 6.470
# INFO:tensorflow:Epoch 1/12, Global Step: 2131
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.306sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.260%
# INFO:tensorflow:Current Realtime Accuracy: 45.312%
# INFO:tensorflow:Current Loss: 6.004
# INFO:tensorflow:Epoch 1/12, Global Step: 2141
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.297sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.266%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 5.816
# INFO:tensorflow:Epoch 1/12, Global Step: 2151
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.322sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.262%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 6.277
# INFO:tensorflow:Epoch 1/12, Global Step: 2161
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.286sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.261%
# INFO:tensorflow:Current Realtime Accuracy: 44.531%
# INFO:tensorflow:Current Loss: 6.152
# INFO:tensorflow:Epoch 1/12, Global Step: 2171
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.308sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.252%
# INFO:tensorflow:Current Realtime Accuracy: 38.281%
# INFO:tensorflow:Current Loss: 6.538
# INFO:tensorflow:Epoch 1/12, Global Step: 2181
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.292sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.242%
# INFO:tensorflow:Current Realtime Accuracy: 49.219%
# INFO:tensorflow:Current Loss: 5.719
# INFO:tensorflow:Epoch 1/12, Global Step: 2191
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.309sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.242%
# INFO:tensorflow:Current Realtime Accuracy: 43.750%
# INFO:tensorflow:Current Loss: 5.968
# INFO:tensorflow:Epoch 1/12, Global Step: 2201
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.297sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.251%
# INFO:tensorflow:Current Realtime Accuracy: 49.219%
# INFO:tensorflow:Current Loss: 5.519
# INFO:tensorflow:Epoch 1/12, Global Step: 2211
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.308sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.260%
# INFO:tensorflow:Current Realtime Accuracy: 39.062%
# INFO:tensorflow:Current Loss: 6.388
# INFO:tensorflow:Epoch 1/12, Global Step: 2221
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.318sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.257%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 6.589
# INFO:tensorflow:Epoch 1/12, Global Step: 2231
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.287sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.254%
# INFO:tensorflow:Current Realtime Accuracy: 34.375%
# INFO:tensorflow:Current Loss: 6.486
# INFO:tensorflow:Epoch 1/12, Global Step: 2241
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.315sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.245%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 6.009
# INFO:tensorflow:Epoch 1/12, Global Step: 2251
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.299sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.238%
# INFO:tensorflow:Current Realtime Accuracy: 35.938%
# INFO:tensorflow:Current Loss: 6.792
# INFO:tensorflow:Epoch 1/12, Global Step: 2261
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.293sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.223%
# INFO:tensorflow:Current Realtime Accuracy: 49.219%
# INFO:tensorflow:Current Loss: 5.748
# INFO:tensorflow:Epoch 1/12, Global Step: 2271
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.321sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.227%
# INFO:tensorflow:Current Realtime Accuracy: 42.969%
# INFO:tensorflow:Current Loss: 6.452
# INFO:tensorflow:Epoch 1/12, Global Step: 2281
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.298sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.234%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 6.086
# INFO:tensorflow:Epoch 1/12, Global Step: 2291
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.340sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.229%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 5.474
# INFO:tensorflow:Epoch 1/12, Global Step: 2301
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.308sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.233%
# INFO:tensorflow:Current Realtime Accuracy: 38.281%
# INFO:tensorflow:Current Loss: 6.273
# INFO:tensorflow:Epoch 1/12, Global Step: 2311
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.307sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.230%
# INFO:tensorflow:Current Realtime Accuracy: 48.438%
# INFO:tensorflow:Current Loss: 5.928
# INFO:tensorflow:Epoch 1/12, Global Step: 2321
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.308sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.233%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.997
# INFO:tensorflow:Epoch 1/12, Global Step: 2331
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.308sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.239%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 5.713
# INFO:tensorflow:Epoch 1/12, Global Step: 2341
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.299sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.242%
# INFO:tensorflow:Current Realtime Accuracy: 53.906%
# INFO:tensorflow:Current Loss: 5.408
# INFO:tensorflow:Epoch 1/12, Global Step: 2351
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.307sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.245%
# INFO:tensorflow:Current Realtime Accuracy: 37.500%
# INFO:tensorflow:Current Loss: 6.839
# INFO:tensorflow:Epoch 1/12, Global Step: 2361
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.298sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.251%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 6.073
# INFO:tensorflow:Epoch 1/12, Global Step: 2371
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.319sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.252%
# INFO:tensorflow:Current Realtime Accuracy: 36.719%
# INFO:tensorflow:Current Loss: 6.257
# INFO:tensorflow:Epoch 1/12, Global Step: 2381
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:global_step/sec: 3.24167
# INFO:tensorflow:Current Speed: 0.314sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.248%
# INFO:tensorflow:Current Realtime Accuracy: 40.625%
# INFO:tensorflow:Current Loss: 6.438
# INFO:tensorflow:Epoch 1/12, Global Step: 2391
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.305sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.248%
# INFO:tensorflow:Current Realtime Accuracy: 40.625%
# INFO:tensorflow:Current Loss: 6.138
# INFO:tensorflow:Epoch 1/12, Global Step: 2401
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.300sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.237%
# INFO:tensorflow:Current Realtime Accuracy: 48.438%
# INFO:tensorflow:Current Loss: 5.818
# INFO:tensorflow:Epoch 1/12, Global Step: 2411
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.303sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.241%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 6.181
# INFO:tensorflow:Epoch 1/12, Global Step: 2421
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.313sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.233%
# INFO:tensorflow:Current Realtime Accuracy: 52.344%
# INFO:tensorflow:Current Loss: 5.476
# INFO:tensorflow:Epoch 1/12, Global Step: 2431
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.353sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.240%
# INFO:tensorflow:Current Realtime Accuracy: 47.656%
# INFO:tensorflow:Current Loss: 5.952
# INFO:tensorflow:Epoch 1/12, Global Step: 2441
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.306sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.243%
# INFO:tensorflow:Current Realtime Accuracy: 46.094%
# INFO:tensorflow:Current Loss: 6.031
# INFO:tensorflow:Epoch 1/12, Global Step: 2451
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.310sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.247%
# INFO:tensorflow:Current Realtime Accuracy: 48.438%
# INFO:tensorflow:Current Loss: 5.609
# INFO:tensorflow:Epoch 1/12, Global Step: 2461
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.318sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.242%
# INFO:tensorflow:Current Realtime Accuracy: 52.344%
# INFO:tensorflow:Current Loss: 5.242
# INFO:tensorflow:Epoch 1/12, Global Step: 2471
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.297sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.252%
# INFO:tensorflow:Current Realtime Accuracy: 53.906%
# INFO:tensorflow:Current Loss: 5.178
# INFO:tensorflow:Epoch 1/12, Global Step: 2481
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.311sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.267%
# INFO:tensorflow:Current Realtime Accuracy: 46.875%
# INFO:tensorflow:Current Loss: 5.469
# INFO:tensorflow:Epoch 1/12, Global Step: 2491
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.309sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.269%
# INFO:tensorflow:Current Realtime Accuracy: 40.625%
# INFO:tensorflow:Current Loss: 6.121
# INFO:tensorflow:Epoch 1/12, Global Step: 2501
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.304sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.269%
# INFO:tensorflow:Current Realtime Accuracy: 50.000%
# INFO:tensorflow:Current Loss: 5.763
# INFO:tensorflow:Epoch 1/12, Global Step: 2511
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# INFO:tensorflow:Current Speed: 0.323sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 44.275%
# INFO:tensorflow:Current Realtime Accuracy: 41.406%
# INFO:tensorflow:Current Loss: 5.936
# INFO:tensorflow:Epoch 1/12, Global Step: 2521
# INFO:tensorflow:Current Learning Rate: 0.0010000000474974513
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ea2852d88fcf> in <module>()
#      64
#      65             with tf.device('/gpu:0'):
# ---> 66                 _, _, cur_loss, cur_acc, rt_accuracy, total_step, cur_lr = sess.run([train_op, metrics_op, total_loss, accuracy, real_time_accuracy, global_step, lr], feed_dict={lr: cur_readed_lr})
#      67             time_elapsed = time.time() - start_time
#      68
#
# /home/kapok/pyenv35/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/kapok/pyenv35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /home/kapok/pyenv35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/kapok/pyenv35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /home/kapok/pyenv35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
