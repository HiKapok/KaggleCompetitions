# %%
# Running %env without any arguments
# lists all environment variables

# The line below sets the environment
# variable CUDA_VISIBLE_DEVICES
# %env CUDA_VISIBLE_DEVICES = 0

import numpy as np
import pandas as pd
import io
import time
import bson                       # this is installed with the pymongo package
import matplotlib.pyplot as plt
from scipy.misc import imread, imsave, imshow
import tensorflow as tf
from tensorflow.python.platform import tf_logging
from tensorflow.contrib import layers
from tensorflow.contrib.training import add_gradients_summaries
from tensorflow.python.ops import math_ops
from tensorflow.python.framework import ops
from tensorflow.python.ops import array_ops
from tensorflow.python.ops import nn_ops
from tensorflow.python.ops import control_flow_ops
from tensorflow.python.training import optimizer as tf_optimizer
from tensorflow.python.ops import variables as tf_variables
import os.path
import tensorflow.contrib.slim as slim
import inception_preprocessing
import logging
import resnet2

# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# last count: 9817, roughly examples num: 10052608
# after resample count: 18456575

# '/media/rs/FC6CDC6F6CDC25E4/resample_dataset2/'
# total sampled examples num: 18456575

# %%
DATASET_PATH = '/media/rs/0E06CD1706CD0127/Kapok/kaggle/'
PRETRAINED_MODEL_PATH = DATASET_PATH + 'Resnet/resnet2/resnet_v2_101.ckpt'
LOG_PATH = DATASET_PATH + 'Resnet/logs101/'
#TRAIN_PATH = DATASET_PATH + 'Split1/Train/'
TRAIN_PATH = '/media/rs/FC6CDC6F6CDC25E4/resample_dataset2/'
VAL_PATH = DATASET_PATH + 'Split1/Validation/'
TEST_PATH = DATASET_PATH + 'Test/'
CATEGORY_NAME_PATH = DATASET_PATH + 'category_names.csv'
BATCH_SIZE = 128#256

# total_batch_size is BATCH_SIZE * ACCUMULATE_STEP
ACCUMULATE_STEP = 2

IMAGE_WIDTH = 180
IMAGE_HEIGHT = 180
NUM_CLASS = 5270
LEVEL0_CLASS = 49
LEVEL1_CLASS = 483
# validation examples num: 2319624
# train examples num: 10051704
# total step: 157057
# start 141310, change balance
# start 158987, delete val
TOTAL_EXAMPLES = 10051704
VAL_EXAMPLES = 2319624
VAL_CHECK_FREQ = 200
NUM_EPOCHES = 12
VAL_NUM_EPOCHES = int(NUM_EPOCHES/(VAL_CHECK_FREQ*VAL_EXAMPLES/TOTAL_EXAMPLES)) + 1
EPOCHES_OVER = 8

INPUT_THREADS = 12

#Learning rate information and configuration (Up to you to experiment)
# initial_learning_rate = 0.000003#0.00001
# learning_rate_decay_factor = 0.94
initial_learning_rate = 0.001#0.0004
stop_learning_rate = 0.000002
learning_rate_decay_factor = 0.94#0.8
num_epochs_before_decay = 1
moving_average_decay = 0.95# use large to be more stable?
momentum = 0.8
#Know the number steps to take before decaying the learning rate and batches per epoch
num_steps_per_epoch = TOTAL_EXAMPLES / (BATCH_SIZE * ACCUMULATE_STEP) + 1
decay_steps = int(num_epochs_before_decay * num_steps_per_epoch / 6)

# %%
# get TF logger
log = logging.getLogger('tensorflow')
log.setLevel(logging.DEBUG)

# create formatter and add it to the handlers
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# create file handler which logs even debug messages
fh = logging.FileHandler(DATASET_PATH + 'tensorflow_resnet_train.log')
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)
log.addHandler(fh)

# %%
def preprocess_for_inception(input_image, is_training = True):
    return inception_preprocessing.preprocess_image(input_image, 160, 160, is_training)

# %%
class LabelMapping(object):
    def __init__(self, catogory_file_path):
        super(LabelMapping, self).__init__()
        self._category_level_csv = catogory_file_path
        self._category_map, self._category_level0_map, self._category_level1_map, self._len_level0, self._len_level1 = self.cvt_csv2tfrecord()
        self._mapping_strings = tf.constant( [ str(key) for key in self._category_map.keys() ] )
        #print(list(self._category_map.keys())[0])
        self._mapping_table = tf.contrib.lookup.index_table_from_tensor(mapping=self._mapping_strings, default_value=0) 
        
        self._level0_table = tf.contrib.lookup.HashTable(tf.contrib.lookup.KeyValueTensorInitializer(list(self._category_level0_map.keys()), list(self._category_level0_map.values()), tf.int64, tf.int64), 0)
        self._level1_table = tf.contrib.lookup.HashTable(tf.contrib.lookup.KeyValueTensorInitializer(list(self._category_level1_map.keys()), list(self._category_level1_map.values()), tf.int64, tf.int64), 0)

    @property
    def category_map(self):
        return self._category_map
    @property
    def level0_table(self):
        return self._level0_table
    @property
    def level1_table(self):
        return self._level1_table
    @property
    def len_level0(self):
        return self._len_level0
    @property
    def len_level1(self):
        return self._len_level1
    @property
    def mapping_table(self):
        return self._mapping_table
    
    def cvt_csv2tfrecord(self):
        level0_map, level1_map = self.create_level_map()
        count = 0
        category_map = dict()
        category_level0_map = dict()
        category_level1_map = dict()
        csv = pd.read_csv(self._category_level_csv).values
        for row in csv:  
            category_id, level0, level1 = row[0], row[1], row[2]
            category_map[category_id] = count
            category_level0_map[int(category_id)] = level0_map[level0]
            category_level1_map[int(category_id)] = level1_map[level1]
            count += 1

        return category_map, category_level0_map, category_level1_map, len(level0_map), len(level1_map)

    def create_level_map(self):
        csv = pd.read_csv(self._category_level_csv).values
        level_list = [list(), list()]
        for row in csv: 
            for level in range(1,3):
                if row[level] not in level_list[level-1]:
                    level_list[level-1].append(row[level])
        return dict(zip(level_list[0], range(len(level_list[0])))), dict(zip(level_list[1], range(len(level_list[1]))))

# %%
class CdiscountDataset(object):
    def __init__(self, data_path, file_begin_match, label_mapping, num_examples, num_classes, buffer_size, batch_size, num_epochs, is_training):
        super(CdiscountDataset, self).__init__()
        #self._data_file_list = [ os.path.join(data_path, x) for x in os.listdir(data_path) if lambda x: os.path.isfile(x) and x.startswith(file_begin_match) ]
        self._data_file_list = data_path + file_begin_match + '*'
        self._num_examples = num_examples
        self._num_classes = num_classes
        self._batch_size = batch_size
        self._buffer_size = buffer_size
        self._num_epochs = num_epochs
        self._is_training = is_training
        self._category_map = label_mapping.category_map
        self._level0_table = label_mapping.level0_table
        self._level1_table = label_mapping.level1_table
        self._len_level0 = label_mapping.len_level0
        self._len_level1 = label_mapping.len_level1
        self._mapping_table = label_mapping.mapping_table
    
    
    def create_dataset(self):
        opts = tf.python_io.TFRecordOptions(tf.python_io.TFRecordCompressionType.ZLIB)
        reader = lambda : tf.TFRecordReader(options=opts)
        keys_to_features = {
            'img_raw': tf.FixedLenFeature([], tf.string, default_value=''),
            'product_id': tf.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64)),
            # notice that we don't have this feature in our TFRecord, so always default provided
            'format': tf.FixedLenFeature([], tf.string, default_value='jpg'),
            'category_id': tf.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
        }

        items_to_handlers = {
            # automated decode image from features in FixedLenFeature
            'image': slim.tfexample_decoder.Image(image_key='img_raw', format_key='format'),
            'label': slim.tfexample_decoder.Tensor('category_id'),
        }

        decoder = slim.tfexample_decoder.TFExampleDecoder(keys_to_features, items_to_handlers)
        
        self._dataset = slim.dataset.Dataset(
            data_sources = self._data_file_list,
            decoder = decoder,
            reader = reader,
            # num_readers = 8,
            num_samples = self._num_examples,
            #num_classes = self._num_classes,
            items_to_descriptions = None)
        
        # notice that DatasetDataProvider can automate shuffle the examples by ParallelReader using its RandomShuffleQueue
        self._data_provider = slim.dataset_data_provider.DatasetDataProvider(
            self._dataset,
            num_readers = INPUT_THREADS,
            shuffle = True, # default is True
            num_epochs = self._num_epochs,
            common_queue_capacity = self._buffer_size + 4 * self._batch_size,
            common_queue_min = self._buffer_size,
            scope = self._is_training and 'train_files' or 'validation_files')
        
        org_image, org_label = self._data_provider.get(['image', 'label'])

        image = preprocess_for_inception(org_image, self._is_training) # final image to train
 
        # no need for shuffle, DatasetDataProvider do this for us
        batch_images, batch_labels, batch_labels_level0, batch_labels_level1 = \
                tf.train.batch([image, tf.one_hot(self._mapping_table.lookup(tf.as_string(org_label)), self._num_classes, axis=-1),\
                tf.one_hot(self._level0_table.lookup(org_label), self._len_level0, axis=-1),\
                tf.one_hot(self._level1_table.lookup(org_label), self._len_level1, axis=-1)],\
                self._batch_size,\
                num_threads = INPUT_THREADS,\
                capacity = self._buffer_size + 4 * self._batch_size,\
                allow_smaller_final_batch = self._is_training, name = self._is_training and 'train_batch' or 'validation_batch')
        
        return batch_images, batch_labels, batch_labels_level0, batch_labels_level1

# %%
def my_create_train_op(total_loss, optimizer, summarize_gradients = False, accumulate_factor=None):
    global_step = tf.train.get_or_create_global_step()

    update_ops = set(ops.get_collection(ops.GraphKeys.UPDATE_OPS))

    # Make sure update_ops are computed before total_loss.
    if update_ops:
        with ops.control_dependencies(update_ops):
            barrier = control_flow_ops.no_op(name='update_barrier')
    total_loss = control_flow_ops.with_dependencies([barrier], total_loss)

    variables_to_train = tf_variables.trainable_variables()

    # initialized with 0s
    accum_vars = [tf.Variable(tf.zeros_like(tv.initialized_value()), trainable=False) for tv in variables_to_train]
    zero_ops = [tv.assign(tf.zeros_like(tv)) for tv in accum_vars]

    # Calls the compute_gradients function of the optimizer to obtain... the list of gradients
    grads = optimizer.compute_gradients(
      total_loss,
      variables_to_train,
      gate_gradients=tf_optimizer.Optimizer.GATE_OP,
      aggregation_method=None,
      colocate_gradients_with_ops=False)

    ## Adds to each element from the list you initialized earlier with zeros its gradient (works because accum_vars and grads are in the same order)
    if accumulate_factor is not None:   
        total_loss = array_ops.check_numerics(total_loss, 'LossTensor is inf or nan')
        with tf.control_dependencies([total_loss]):
            accum_ops = [accum_vars[i].assign_add(gv[0]) for i, gv in enumerate(grads) if gv[0] is not None]

        ## Define the training step (part with variable value update)
        accumulate_grads = [(tf.multiply(accum_vars[i], accumulate_factor), gv[1]) for i, gv in enumerate(grads) if gv[0] is not None]
    else:
        accum_ops = tf.no_op(name = 'accum_pass_by')
    
    if accumulate_factor is not None: 
        # Summarize gradients.
        if summarize_gradients:
            with ops.name_scope('summarize_grads'):
                add_gradients_summaries(accumulate_grads)
        grad_updates = optimizer.apply_gradients(accumulate_grads, global_step=global_step)
    else:
        # Summarize gradients.
        if summarize_gradients:
            with ops.name_scope('summarize_grads'):
                add_gradients_summaries(grads)
        grad_updates = optimizer.apply_gradients(grads, global_step=global_step)

    with ops.name_scope('train_op'):
        # Ensure the train_tensor computes grad_updates.
        train_op = control_flow_ops.with_dependencies([grad_updates], total_loss)

    # Add the operation used for training to the 'train_op' collection
    train_ops = ops.get_collection_ref(ops.GraphKeys.TRAIN_OP)
    if train_op not in train_ops:
        train_ops.append(train_op)

    return train_op, accum_ops, zero_ops

# %%
def_graph = tf.Graph()
with def_graph.as_default() as graph:
    def my_exponential_decay(learning_rate, global_step, decay_steps, decay_rate,
                      staircase=False, name=None):
        if global_step is None:
            raise ValueError("global_step is required for exponential_decay.")
        with ops.name_scope(name, "ExponentialDecay",
                          [learning_rate, global_step,
                           decay_steps, decay_rate]) as name:
            learning_rate = ops.convert_to_tensor(learning_rate, name="learning_rate")
            dtype = learning_rate.dtype
            global_step = math_ops.cast(global_step, dtype)
            decay_steps = math_ops.cast(decay_steps, dtype)
            decay_rate = math_ops.cast(decay_rate, dtype)
            p = global_step / decay_steps
            if staircase:
                p = math_ops.floor(p)
            return tf.maximum(math_ops.multiply(learning_rate, math_ops.pow(decay_rate, p),
                                 name=name), tf.constant(stop_learning_rate, dtype=dtype))
    def train_step(input_examples, one_hot_labels, level0_labels, level1_labels):   
        # inputs has shape [batch, 224, 224, 3]
        with slim.arg_scope(resnet2.resnet_arg_scope()):
            logits, end_points = resnet2.resnet_v2_101(input_examples, NUM_CLASS, is_training=True)
            
            variables_to_restore = slim.get_variables_to_restore(exclude = ['resnet_v2_101/logits'])

            level0_aux_input = def_graph.get_tensor_by_name('resnet_v2_101/block3/unit_23/bottleneck_v2/add:0')
            level1_aux_input = def_graph.get_tensor_by_name('resnet_v2_101/block4/unit_3/bottleneck_v2/add:0')   
           
            level0_aux_input = layers.batch_norm(
                level0_aux_input, activation_fn=nn_ops.relu, scope='postnorm_aux0')
            
            level1_aux_input = layers.batch_norm(
                level1_aux_input, activation_fn=nn_ops.relu, scope='postnorm_aux1')
        
            level0_aux_net = math_ops.reduce_mean(level0_aux_input, [1, 2], name='level0_aux_pool', keep_dims=True)
            level0_aux_net = layers.conv2d(
                  level0_aux_net,
                  LEVEL0_CLASS, [1, 1],
                  activation_fn=None,
                  normalizer_fn=None,
                  scope='level0_aux_conv')
            level0_aux_logits = tf.squeeze(level0_aux_net)
            loss_level0 = tf.losses.softmax_cross_entropy(onehot_labels = level0_labels, logits = level0_aux_logits, weights=0.1, label_smoothing = 0.2)
            level1_aux_net = math_ops.reduce_mean(level1_aux_input, [1, 2], name='level1_aux_pool', keep_dims=True)
            level1_aux_net = layers.conv2d(
                  level1_aux_net,
                  LEVEL1_CLASS, [1, 1],
                  activation_fn=None,
                  normalizer_fn=None,
                  scope='level1_aux_conv')
            level1_aux_logits = tf.squeeze(level1_aux_net)
            loss_level1 = tf.losses.softmax_cross_entropy(onehot_labels = level1_labels, logits = level1_aux_logits, weights=0.3, label_smoothing = 0.2)

            #variables_to_restore_from_checkpoint = slim.get_variables_to_restore(exclude = variables_to_exclude)
            # Performs the equivalent to tf.nn.sparse_softmax_cross_entropy_with_logits but enhanced, e.x. label smothing
            end_points['logits_output_squeezed'] = tf.squeeze(logits)
            loss = tf.losses.softmax_cross_entropy(onehot_labels = one_hot_labels, logits = end_points['logits_output_squeezed'], label_smoothing = 0.1)
            total_loss = tf.losses.get_total_loss()    # obtain the regularization losses as well

            # Create the global step for monitoring the learning_rate and training.
            # since supervisor will also create one global_step, so we create n advance in order to feed into exponential_decay
            global_step = tf.train.get_or_create_global_step(graph = graph)

            #Define your exponentially decaying learning rate
            lr = my_exponential_decay(#tf.train.exponential_decay(
                learning_rate = initial_learning_rate,
                global_step = global_step,
                decay_steps = decay_steps,
                decay_rate = learning_rate_decay_factor,
                staircase = True)

            #Now we can define the optimizer that takes on the learning rate
            optimizer = tf.train.AdamOptimizer(learning_rate = lr)
            #optimizer = tf.train.RMSPropOptimizer(learning_rate = lr)
            #optimizer = tf.train.MomentumOptimizer(learning_rate = lr, momentum=momentum)
            
            # Gather update_ops from the first clone. These contain, for example,
            # the updates for the batch_norm variables created by network_fn.
            # update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

            moving_average_variables = slim.get_model_variables()
            variable_averages = tf.train.ExponentialMovingAverage(moving_average_decay, global_step)
            # Use an alternative set of update ops in addition to the default updates:
            tf.add_to_collection(tf.GraphKeys.UPDATE_OPS, variable_averages.apply(moving_average_variables))

            #Create the train_op.
            accumulate_factor = tf.constant([1./ACCUMULATE_STEP])
            train_op, accum_ops, zero_ops = my_create_train_op(total_loss, optimizer, False, accumulate_factor)
            
            #Create the train_op.
            #train_op = slim.learning.create_train_op(total_loss, optimizer, summarize_gradients=False)

            #State the metrics that you want to predict. We get a predictions that is not one_hot_encoded.
            predictions = tf.argmax(tf.squeeze(end_points['predictions']), 1)
            probabilities = end_points['predictions']
            accuracy, accuracy_update = tf.contrib.metrics.streaming_accuracy(predictions, tf.argmax(one_hot_labels, 1), name='train_accuracy')
            metrics_op = tf.group(accuracy_update)


            #Now finally create all the summaries you need to monitor and group them into one summary op.
            tf.summary.scalar('losses/Total_Loss', total_loss)
            tf.summary.scalar('train/accuracy', accuracy)
            tf.summary.scalar('learning_rate', lr)

            return train_op, accum_ops, zero_ops, global_step, metrics_op, variables_to_restore, predictions, lr, accuracy, total_loss

# %%
with def_graph.as_default() as graph:
    label_mapping = LabelMapping(CATEGORY_NAME_PATH)
    train_dataset = CdiscountDataset(TRAIN_PATH, 'output_file', label_mapping, TOTAL_EXAMPLES, NUM_CLASS, 8000, BATCH_SIZE, NUM_EPOCHES, True)

    batch_images, batch_labels, batch_level0_labels, batch_level1_labels = train_dataset.create_dataset()
    
    with tf.device('/gpu:0'):
        train_op, accum_op, zero_op, global_step, metrics_op, variables_to_restore, pred_op, lr, accuracy, total_loss = train_step(batch_images, batch_labels, batch_level0_labels, batch_level1_labels)
         
    summary_op = tf.summary.merge_all()
    # Create a saver that restores only the pre-trained variables.
    # we have change optim, restore all param use pretrained mode
    #pre_train_saver = tf.train.Saver(variables_to_restore)
    
    variables = slim.get_variables_to_restore()
    restore_from_pretrained = tf.contrib.framework.filter_variables(
        variables,
        include_patterns=None,
        exclude_patterns=['Momentum'])

    restore_from_checkpoint = tf.contrib.framework.filter_variables(
        variables,
        include_patterns=None,
        exclude_patterns=['train_accuracy'])

    checkpoint_saver = tf.train.Saver(restore_from_checkpoint)
    
    pre_train_saver = tf.train.Saver(variables_to_restore)
    # Define an init function that loads the pretrained checkpoint.
    # sess is the managed session passed by Supervisor
    def load_pretrain(sess):
        pre_train_saver.restore(sess, PRETRAINED_MODEL_PATH)

    # no need for specify local_variables_initializer and tables_initializer, Supervisor will do this via default local_init_op
    # init_op = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer(), tf.tables_initializer())
    init_op = tf.group(tf.global_variables_initializer())
    #init_op = tf.group(train_iterator_initializer, val_iterator_initializer, tf.global_variables_initializer())
    
    # Pass the init function to the supervisor.
    # - The init function is called _after_ the variables have been initialized by running the init_op.
    # - use default tf.Saver() for ordinary save and restore
    # - save checkpoint every 1.3 hours(4800)
    # - manage summary in current process by ourselves for memory saving
    # - no need to specify global_step, supervisor will find this automately
    # - initialize order: checkpoint -> local_init_op -> init_op -> init_func
    sv = tf.train.Supervisor(logdir=LOG_PATH, init_fn = load_pretrain, init_op = init_op, summary_op = None, save_model_secs=8000, checkpoint_basename='resnet101_v2_model.ckpt')
    
    final_loss = 0.
    final_accuracy = 0.
    training_state = True

    config = tf.ConfigProto(log_device_placement=True, allow_soft_placement=True)
    #config.gpu_options.allow_growth = True
    with sv.managed_session(config=config) as sess:
    #with sv.prepare_or_wait_for_session(config=tf.ConfigProto(log_device_placement=True, allow_soft_placement=True)) as sess:
        #sess.run(iterator_initalizer)
        # Here sess was either initialized from the pre-trained-checkpoint or
        # recovered from a checkpoint saved in a previous run of this code.
        for step in range(int(num_steps_per_epoch * NUM_EPOCHES)):         
            if sv.should_stop():
                tf_logging.info('Supervisor emit finished!')
                tf_logging.info('Current Loss: %s', loss)
                tf_logging.info('Current Accuracy: %s', accuracy)
                tf_logging.info('Saving current model to disk(maybe invalid).')
                training_state = False
                break

            start_time = time.time()

            if step % 1000 == 0:
                summ = sess.run(summary_op)
                sv.summary_computed(sess, summ)
                if step > EPOCHES_OVER * num_steps_per_epoch:
                    raise StopIteration("over epoches reached.")
            
            with tf.device('/gpu:0'):
                # accumulate gradient to get bigger batch_size
                sess.run(zero_op)
                for _ in range(1, ACCUMULATE_STEP):
                    sess.run([accum_op, total_loss])
                _, _, _, cur_loss, cur_acc, total_step, cur_lr = sess.run([train_op, accum_op, metrics_op, total_loss, accuracy, global_step, lr])
#                     sess.run([train_op])
            time_elapsed = time.time() - start_time

            if step % 10 == 0:
                final_loss = cur_loss
                final_accuracy = cur_acc
                tf_logging.info('Current Speed: {:5.3f}sec/batch'.format(time_elapsed))
                tf_logging.info('Current Streaming Accuracy: {:5.3f}%'.format(cur_acc*100.))
                tf_logging.info('Current Loss: {:5.3f}'.format(cur_loss))
                tf_logging.info('Epoch %s/%s, Global Step: %s', int(total_step / num_steps_per_epoch + 1), NUM_EPOCHES, total_step)
                tf_logging.info('Current Learning Rate: {}'.format(cur_lr))


        if training_state:
            #We log the final training loss and accuracy
            tf_logging.info('Final Loss: %s', final_loss)
            tf_logging.info('Final Accuracy: %s', final_accuracy)
            # Once all the training has been done, save the log files and checkpoint model
            tf_logging.info('Finished training! Model saved.')
        sv.saver.save(sess, sv.save_path, global_step = sv.global_step)
# Out:
# INFO:tensorflow:Restoring parameters from /media/rs/0E06CD1706CD0127/Kapok/kaggle/Resnet/logs101/resnet101_v2_model.ckpt-158988
# INFO:tensorflow:Starting standard services.
# INFO:tensorflow:Saving checkpoint to path /media/rs/0E06CD1706CD0127/Kapok/kaggle/Resnet/logs101/resnet101_v2_model.ckpt
# INFO:tensorflow:Starting queue runners.
# INFO:tensorflow:global_step/sec: 0
# INFO:tensorflow:Current Speed: 26.128sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 0.000%
# INFO:tensorflow:Current Loss: 6.747
# INFO:tensorflow:Epoch 5/12, Global Step: 158989
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.575sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 29.531%
# INFO:tensorflow:Current Loss: 6.720
# INFO:tensorflow:Epoch 5/12, Global Step: 158999
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.697sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.227%
# INFO:tensorflow:Current Loss: 6.426
# INFO:tensorflow:Epoch 5/12, Global Step: 159009
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.694sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.708%
# INFO:tensorflow:Current Loss: 6.582
# INFO:tensorflow:Epoch 5/12, Global Step: 159019
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.711sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.832%
# INFO:tensorflow:Current Loss: 6.386
# INFO:tensorflow:Epoch 5/12, Global Step: 159029
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.707sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 33.094%
# INFO:tensorflow:Current Loss: 6.198
# INFO:tensorflow:Epoch 5/12, Global Step: 159039
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:global_step/sec: 0.474818
# INFO:tensorflow:Current Speed: 1.696sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 33.437%
# INFO:tensorflow:Current Loss: 6.614
# INFO:tensorflow:Epoch 5/12, Global Step: 159049
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.694sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 33.304%
# INFO:tensorflow:Current Loss: 6.629
# INFO:tensorflow:Epoch 5/12, Global Step: 159059
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.775sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 33.125%
# INFO:tensorflow:Current Loss: 6.310
# INFO:tensorflow:Epoch 5/12, Global Step: 159069
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.701sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 33.307%
# INFO:tensorflow:Current Loss: 6.292
# INFO:tensorflow:Epoch 5/12, Global Step: 159079
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.715sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 33.156%
# INFO:tensorflow:Current Loss: 6.784
# INFO:tensorflow:Epoch 5/12, Global Step: 159089
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.704sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 33.097%
# INFO:tensorflow:Current Loss: 6.402
# INFO:tensorflow:Epoch 5/12, Global Step: 159099
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.712sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 33.008%
# INFO:tensorflow:Current Loss: 6.704
# INFO:tensorflow:Epoch 5/12, Global Step: 159109
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:global_step/sec: 0.583556
# INFO:tensorflow:Current Speed: 1.741sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.861%
# INFO:tensorflow:Current Loss: 6.683
# INFO:tensorflow:Epoch 5/12, Global Step: 159119
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.732sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.980%
# INFO:tensorflow:Current Loss: 6.939
# INFO:tensorflow:Epoch 5/12, Global Step: 159129
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.715sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.906%
# INFO:tensorflow:Current Loss: 7.040
# INFO:tensorflow:Epoch 5/12, Global Step: 159139
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.719sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.866%
# INFO:tensorflow:Current Loss: 6.917
# INFO:tensorflow:Epoch 5/12, Global Step: 159149
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.700sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.633%
# INFO:tensorflow:Current Loss: 6.809
# INFO:tensorflow:Epoch 5/12, Global Step: 159159
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.741sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.626%
# INFO:tensorflow:Current Loss: 6.372
# INFO:tensorflow:Epoch 5/12, Global Step: 159169
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.703sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.516%
# INFO:tensorflow:Current Loss: 6.575
# INFO:tensorflow:Epoch 5/12, Global Step: 159179
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:global_step/sec: 0.574996
# INFO:tensorflow:Current Speed: 1.699sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.559%
# INFO:tensorflow:Current Loss: 6.922
# INFO:tensorflow:Epoch 5/12, Global Step: 159189
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.723sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.604%
# INFO:tensorflow:Current Loss: 6.686
# INFO:tensorflow:Epoch 5/12, Global Step: 159199
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.719sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.642%
# INFO:tensorflow:Current Loss: 6.905
# INFO:tensorflow:Epoch 5/12, Global Step: 159209
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.751sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.649%
# INFO:tensorflow:Current Loss: 6.659
# INFO:tensorflow:Epoch 5/12, Global Step: 159219
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.746sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.692%
# INFO:tensorflow:Current Loss: 6.464
# INFO:tensorflow:Epoch 5/12, Global Step: 159229
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.702sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.634%
# INFO:tensorflow:Current Loss: 6.582
# INFO:tensorflow:Epoch 5/12, Global Step: 159239
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.734sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.680%
# INFO:tensorflow:Current Loss: 6.513
# INFO:tensorflow:Epoch 5/12, Global Step: 159249
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:global_step/sec: 0.583338
# INFO:tensorflow:Current Speed: 1.720sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.630%
# INFO:tensorflow:Current Loss: 7.109
# INFO:tensorflow:Epoch 5/12, Global Step: 159259
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.728sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.626%
# INFO:tensorflow:Current Loss: 6.948
# INFO:tensorflow:Epoch 5/12, Global Step: 159269
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.741sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.605%
# INFO:tensorflow:Current Loss: 6.863
# INFO:tensorflow:Epoch 5/12, Global Step: 159279
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.715sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.594%
# INFO:tensorflow:Current Loss: 6.830
# INFO:tensorflow:Epoch 5/12, Global Step: 159289
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.731sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.601%
# INFO:tensorflow:Current Loss: 6.947
# INFO:tensorflow:Epoch 5/12, Global Step: 159299
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.708sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.571%
# INFO:tensorflow:Current Loss: 6.848
# INFO:tensorflow:Epoch 5/12, Global Step: 159309
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.730sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.538%
# INFO:tensorflow:Current Loss: 6.751
# INFO:tensorflow:Epoch 5/12, Global Step: 159319
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:global_step/sec: 0.575
# INFO:tensorflow:Current Speed: 1.723sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.539%
# INFO:tensorflow:Current Loss: 6.811
# INFO:tensorflow:Epoch 5/12, Global Step: 159329
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.764sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.504%
# INFO:tensorflow:Current Loss: 7.026
# INFO:tensorflow:Epoch 5/12, Global Step: 159339
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.743sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.498%
# INFO:tensorflow:Current Loss: 6.679
# INFO:tensorflow:Epoch 5/12, Global Step: 159349
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.715sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.485%
# INFO:tensorflow:Current Loss: 6.831
# INFO:tensorflow:Epoch 5/12, Global Step: 159359
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.728sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.477%
# INFO:tensorflow:Current Loss: 6.574
# INFO:tensorflow:Epoch 5/12, Global Step: 159369
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.727sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.420%
# INFO:tensorflow:Current Loss: 6.760
# INFO:tensorflow:Epoch 5/12, Global Step: 159379
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.728sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.457%
# INFO:tensorflow:Current Loss: 6.781
# INFO:tensorflow:Epoch 5/12, Global Step: 159389
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:global_step/sec: 0.575
# INFO:tensorflow:Current Speed: 1.746sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.471%
# INFO:tensorflow:Current Loss: 6.522
# INFO:tensorflow:Epoch 5/12, Global Step: 159399
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.777sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.452%
# INFO:tensorflow:Current Loss: 7.064
# INFO:tensorflow:Epoch 5/12, Global Step: 159409
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.719sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.420%
# INFO:tensorflow:Current Loss: 6.939
# INFO:tensorflow:Epoch 5/12, Global Step: 159419
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.776sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.379%
# INFO:tensorflow:Current Loss: 6.502
# INFO:tensorflow:Epoch 5/12, Global Step: 159429
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.738sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.361%
# INFO:tensorflow:Current Loss: 7.137
# INFO:tensorflow:Epoch 5/12, Global Step: 159439
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.734sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.337%
# INFO:tensorflow:Current Loss: 6.993
# INFO:tensorflow:Epoch 5/12, Global Step: 159449
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.702sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.312%
# INFO:tensorflow:Current Loss: 6.567
# INFO:tensorflow:Epoch 5/12, Global Step: 159459
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:global_step/sec: 0.583332
# INFO:tensorflow:Current Speed: 1.762sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.275%
# INFO:tensorflow:Current Loss: 6.672
# INFO:tensorflow:Epoch 5/12, Global Step: 159469
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.706sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.246%
# INFO:tensorflow:Current Loss: 6.424
# INFO:tensorflow:Epoch 5/12, Global Step: 159479
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.757sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.233%
# INFO:tensorflow:Current Loss: 6.856
# INFO:tensorflow:Epoch 5/12, Global Step: 159489
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.706sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.192%
# INFO:tensorflow:Current Loss: 6.820
# INFO:tensorflow:Epoch 5/12, Global Step: 159499
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.721sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.181%
# INFO:tensorflow:Current Loss: 6.915
# INFO:tensorflow:Epoch 5/12, Global Step: 159509
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.729sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.164%
# INFO:tensorflow:Current Loss: 6.901
# INFO:tensorflow:Epoch 5/12, Global Step: 159519
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.700sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.140%
# INFO:tensorflow:Current Loss: 6.776
# INFO:tensorflow:Epoch 5/12, Global Step: 159529
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:global_step/sec: 0.575002
# INFO:tensorflow:Current Speed: 1.740sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.172%
# INFO:tensorflow:Current Loss: 7.094
# INFO:tensorflow:Epoch 5/12, Global Step: 159539
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.760sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.118%
# INFO:tensorflow:Current Loss: 7.002
# INFO:tensorflow:Epoch 5/12, Global Step: 159549
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.688sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.101%
# INFO:tensorflow:Current Loss: 6.558
# INFO:tensorflow:Epoch 5/12, Global Step: 159559
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.717sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.108%
# INFO:tensorflow:Current Loss: 6.790
# INFO:tensorflow:Epoch 5/12, Global Step: 159569
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.705sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.128%
# INFO:tensorflow:Current Loss: 6.378
# INFO:tensorflow:Epoch 5/12, Global Step: 159579
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.718sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.139%
# INFO:tensorflow:Current Loss: 6.862
# INFO:tensorflow:Epoch 5/12, Global Step: 159589
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.710sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.144%
# INFO:tensorflow:Current Loss: 6.620
# INFO:tensorflow:Epoch 5/12, Global Step: 159599
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:global_step/sec: 0.574999
# INFO:tensorflow:Current Speed: 1.731sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.136%
# INFO:tensorflow:Current Loss: 6.651
# INFO:tensorflow:Epoch 5/12, Global Step: 159609
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.715sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.134%
# INFO:tensorflow:Current Loss: 7.006
# INFO:tensorflow:Epoch 5/12, Global Step: 159619
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.731sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.135%
# INFO:tensorflow:Current Loss: 6.690
# INFO:tensorflow:Epoch 5/12, Global Step: 159629
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.831sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.119%
# INFO:tensorflow:Current Loss: 7.081
# INFO:tensorflow:Epoch 5/12, Global Step: 159639
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.785sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.096%
# INFO:tensorflow:Current Loss: 6.644
# INFO:tensorflow:Epoch 5/12, Global Step: 159649
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.751sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.063%
# INFO:tensorflow:Current Loss: 6.840
# INFO:tensorflow:Epoch 5/12, Global Step: 159659
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.792sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.054%
# INFO:tensorflow:Current Loss: 6.673
# INFO:tensorflow:Epoch 5/12, Global Step: 159669
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.780sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.027%
# INFO:tensorflow:Current Loss: 6.904
# INFO:tensorflow:Epoch 5/12, Global Step: 159679
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.836sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.028%
# INFO:tensorflow:Current Loss: 6.996
# INFO:tensorflow:Epoch 5/12, Global Step: 159689
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.795sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.021%
# INFO:tensorflow:Current Loss: 6.693
# INFO:tensorflow:Epoch 5/12, Global Step: 159699
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.756sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.033%
# INFO:tensorflow:Current Loss: 7.060
# INFO:tensorflow:Epoch 5/12, Global Step: 159709
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.770sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.012%
# INFO:tensorflow:Current Loss: 7.015
# INFO:tensorflow:Epoch 5/12, Global Step: 159719
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.759sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.016%
# INFO:tensorflow:Current Loss: 7.140
# INFO:tensorflow:Epoch 5/12, Global Step: 159729
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.808sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 32.000%
# INFO:tensorflow:Current Loss: 7.352
# INFO:tensorflow:Epoch 5/12, Global Step: 159739
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.847sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.980%
# INFO:tensorflow:Current Loss: 7.131
# INFO:tensorflow:Epoch 5/12, Global Step: 159749
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.777sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.972%
# INFO:tensorflow:Current Loss: 6.480
# INFO:tensorflow:Epoch 5/12, Global Step: 159759
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.796sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.990%
# INFO:tensorflow:Current Loss: 6.580
# INFO:tensorflow:Epoch 5/12, Global Step: 159769
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.760sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.952%
# INFO:tensorflow:Current Loss: 6.785
# INFO:tensorflow:Epoch 5/12, Global Step: 159779
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.831sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.956%
# INFO:tensorflow:Current Loss: 6.908
# INFO:tensorflow:Epoch 5/12, Global Step: 159789
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.825sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.955%
# INFO:tensorflow:Current Loss: 6.617
# INFO:tensorflow:Epoch 5/12, Global Step: 159799
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.767sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.970%
# INFO:tensorflow:Current Loss: 7.080
# INFO:tensorflow:Epoch 5/12, Global Step: 159809
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.833sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.908%
# INFO:tensorflow:Current Loss: 6.991
# INFO:tensorflow:Epoch 5/12, Global Step: 159819
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.833sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.897%
# INFO:tensorflow:Current Loss: 7.094
# INFO:tensorflow:Epoch 5/12, Global Step: 159829
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.777sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.883%
# INFO:tensorflow:Current Loss: 6.924
# INFO:tensorflow:Epoch 5/12, Global Step: 159839
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.840sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.850%
# INFO:tensorflow:Current Loss: 6.905
# INFO:tensorflow:Epoch 5/12, Global Step: 159849
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.846sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.843%
# INFO:tensorflow:Current Loss: 7.175
# INFO:tensorflow:Epoch 5/12, Global Step: 159859
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.774sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.832%
# INFO:tensorflow:Current Loss: 6.939
# INFO:tensorflow:Epoch 5/12, Global Step: 159869
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.779sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.850%
# INFO:tensorflow:Current Loss: 6.767
# INFO:tensorflow:Epoch 5/12, Global Step: 159879
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.738sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.839%
# INFO:tensorflow:Current Loss: 6.895
# INFO:tensorflow:Epoch 5/12, Global Step: 159889
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.795sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.840%
# INFO:tensorflow:Current Loss: 7.019
# INFO:tensorflow:Epoch 5/12, Global Step: 159899
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.755sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.810%
# INFO:tensorflow:Current Loss: 7.256
# INFO:tensorflow:Epoch 5/12, Global Step: 159909
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.859sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.788%
# INFO:tensorflow:Current Loss: 6.906
# INFO:tensorflow:Epoch 5/12, Global Step: 159919
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.849sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.762%
# INFO:tensorflow:Current Loss: 7.178
# INFO:tensorflow:Epoch 5/12, Global Step: 159929
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.803sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.755%
# INFO:tensorflow:Current Loss: 6.936
# INFO:tensorflow:Epoch 5/12, Global Step: 159939
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.761sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.758%
# INFO:tensorflow:Current Loss: 7.079
# INFO:tensorflow:Epoch 5/12, Global Step: 159949
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.816sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.775%
# INFO:tensorflow:Current Loss: 7.262
# INFO:tensorflow:Epoch 5/12, Global Step: 159959
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.777sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.768%
# INFO:tensorflow:Current Loss: 7.042
# INFO:tensorflow:Epoch 5/12, Global Step: 159969
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.707sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.764%
# INFO:tensorflow:Current Loss: 6.862
# INFO:tensorflow:Epoch 5/12, Global Step: 159979
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 2.127sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.762%
# INFO:tensorflow:Current Loss: 7.063
# INFO:tensorflow:Epoch 5/12, Global Step: 159989
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.695sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.739%
# INFO:tensorflow:Current Loss: 6.945
# INFO:tensorflow:Epoch 5/12, Global Step: 159999
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.714sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.736%
# INFO:tensorflow:Current Loss: 7.018
# INFO:tensorflow:Epoch 5/12, Global Step: 160009
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.728sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.717%
# INFO:tensorflow:Current Loss: 7.090
# INFO:tensorflow:Epoch 5/12, Global Step: 160019
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.734sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.707%
# INFO:tensorflow:Current Loss: 7.232
# INFO:tensorflow:Epoch 5/12, Global Step: 160029
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.712sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.693%
# INFO:tensorflow:Current Loss: 6.775
# INFO:tensorflow:Epoch 5/12, Global Step: 160039
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.701sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.688%
# INFO:tensorflow:Current Loss: 6.688
# INFO:tensorflow:Epoch 5/12, Global Step: 160049
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.698sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.698%
# INFO:tensorflow:Current Loss: 7.181
# INFO:tensorflow:Epoch 5/12, Global Step: 160059
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.705sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.686%
# INFO:tensorflow:Current Loss: 6.835
# INFO:tensorflow:Epoch 5/12, Global Step: 160069
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.736sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.685%
# INFO:tensorflow:Current Loss: 6.697
# INFO:tensorflow:Epoch 5/12, Global Step: 160079
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.721sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.683%
# INFO:tensorflow:Current Loss: 6.801
# INFO:tensorflow:Epoch 5/12, Global Step: 160089
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.711sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.689%
# INFO:tensorflow:Current Loss: 7.113
# INFO:tensorflow:Epoch 5/12, Global Step: 160099
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.706sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.676%
# INFO:tensorflow:Current Loss: 6.702
# INFO:tensorflow:Epoch 5/12, Global Step: 160109
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.699sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.679%
# INFO:tensorflow:Current Loss: 6.572
# INFO:tensorflow:Epoch 5/12, Global Step: 160119
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.701sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.671%
# INFO:tensorflow:Current Loss: 7.006
# INFO:tensorflow:Epoch 5/12, Global Step: 160129
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.682sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.673%
# INFO:tensorflow:Current Loss: 6.453
# INFO:tensorflow:Epoch 5/12, Global Step: 160139
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.706sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.675%
# INFO:tensorflow:Current Loss: 6.715
# INFO:tensorflow:Epoch 5/12, Global Step: 160149
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.711sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.665%
# INFO:tensorflow:Current Loss: 7.246
# INFO:tensorflow:Epoch 5/12, Global Step: 160159
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.702sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.658%
# INFO:tensorflow:Current Loss: 6.992
# INFO:tensorflow:Epoch 5/12, Global Step: 160169
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.724sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.645%
# INFO:tensorflow:Current Loss: 6.285
# INFO:tensorflow:Epoch 5/12, Global Step: 160179
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.711sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.651%
# INFO:tensorflow:Current Loss: 7.076
# INFO:tensorflow:Epoch 5/12, Global Step: 160189
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.703sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.644%
# INFO:tensorflow:Current Loss: 6.239
# INFO:tensorflow:Epoch 5/12, Global Step: 160199
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.694sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.637%
# INFO:tensorflow:Current Loss: 7.080
# INFO:tensorflow:Epoch 5/12, Global Step: 160209
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.706sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.645%
# INFO:tensorflow:Current Loss: 6.832
# INFO:tensorflow:Epoch 5/12, Global Step: 160219
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.699sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.622%
# INFO:tensorflow:Current Loss: 6.988
# INFO:tensorflow:Epoch 5/12, Global Step: 160229
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.729sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.608%
# INFO:tensorflow:Current Loss: 6.441
# INFO:tensorflow:Epoch 5/12, Global Step: 160239
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.726sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.594%
# INFO:tensorflow:Current Loss: 6.747
# INFO:tensorflow:Epoch 5/12, Global Step: 160249
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.702sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.596%
# INFO:tensorflow:Current Loss: 7.240
# INFO:tensorflow:Epoch 5/12, Global Step: 160259
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.705sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.580%
# INFO:tensorflow:Current Loss: 6.973
# INFO:tensorflow:Epoch 5/12, Global Step: 160269
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.710sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.574%
# INFO:tensorflow:Current Loss: 6.895
# INFO:tensorflow:Epoch 5/12, Global Step: 160279
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.720sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.561%
# INFO:tensorflow:Current Loss: 6.699
# INFO:tensorflow:Epoch 5/12, Global Step: 160289
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.741sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.551%
# INFO:tensorflow:Current Loss: 6.781
# INFO:tensorflow:Epoch 5/12, Global Step: 160299
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.699sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.548%
# INFO:tensorflow:Current Loss: 7.177
# INFO:tensorflow:Epoch 5/12, Global Step: 160309
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.682sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.540%
# INFO:tensorflow:Current Loss: 7.298
# INFO:tensorflow:Epoch 5/12, Global Step: 160319
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.744sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.543%
# INFO:tensorflow:Current Loss: 7.047
# INFO:tensorflow:Epoch 5/12, Global Step: 160329
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.821sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.525%
# INFO:tensorflow:Current Loss: 6.477
# INFO:tensorflow:Epoch 5/12, Global Step: 160339
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.749sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.533%
# INFO:tensorflow:Current Loss: 6.597
# INFO:tensorflow:Epoch 5/12, Global Step: 160349
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.748sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.528%
# INFO:tensorflow:Current Loss: 6.704
# INFO:tensorflow:Epoch 5/12, Global Step: 160359
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.796sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.527%
# INFO:tensorflow:Current Loss: 6.914
# INFO:tensorflow:Epoch 5/12, Global Step: 160369
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.746sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.535%
# INFO:tensorflow:Current Loss: 6.911
# INFO:tensorflow:Epoch 5/12, Global Step: 160379
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.781sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.529%
# INFO:tensorflow:Current Loss: 6.728
# INFO:tensorflow:Epoch 5/12, Global Step: 160389
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.760sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.517%
# INFO:tensorflow:Current Loss: 7.020
# INFO:tensorflow:Epoch 5/12, Global Step: 160399
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.780sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.518%
# INFO:tensorflow:Current Loss: 6.771
# INFO:tensorflow:Epoch 5/12, Global Step: 160409
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.752sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.516%
# INFO:tensorflow:Current Loss: 7.043
# INFO:tensorflow:Epoch 5/12, Global Step: 160419
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.733sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.521%
# INFO:tensorflow:Current Loss: 7.169
# INFO:tensorflow:Epoch 5/12, Global Step: 160429
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.807sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.491%
# INFO:tensorflow:Current Loss: 7.384
# INFO:tensorflow:Epoch 5/12, Global Step: 160439
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.752sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.482%
# INFO:tensorflow:Current Loss: 6.782
# INFO:tensorflow:Epoch 5/12, Global Step: 160449
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.783sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.472%
# INFO:tensorflow:Current Loss: 7.092
# INFO:tensorflow:Epoch 5/12, Global Step: 160459
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.724sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.480%
# INFO:tensorflow:Current Loss: 6.980
# INFO:tensorflow:Epoch 5/12, Global Step: 160469
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.736sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.484%
# INFO:tensorflow:Current Loss: 6.897
# INFO:tensorflow:Epoch 5/12, Global Step: 160479
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.787sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.475%
# INFO:tensorflow:Current Loss: 7.053
# INFO:tensorflow:Epoch 5/12, Global Step: 160489
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.757sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.463%
# INFO:tensorflow:Current Loss: 6.894
# INFO:tensorflow:Epoch 5/12, Global Step: 160499
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.807sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.453%
# INFO:tensorflow:Current Loss: 6.876
# INFO:tensorflow:Epoch 5/12, Global Step: 160509
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.789sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.438%
# INFO:tensorflow:Current Loss: 6.973
# INFO:tensorflow:Epoch 5/12, Global Step: 160519
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.783sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.441%
# INFO:tensorflow:Current Loss: 7.000
# INFO:tensorflow:Epoch 5/12, Global Step: 160529
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.798sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.425%
# INFO:tensorflow:Current Loss: 6.677
# INFO:tensorflow:Epoch 5/12, Global Step: 160539
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.821sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.425%
# INFO:tensorflow:Current Loss: 6.938
# INFO:tensorflow:Epoch 5/12, Global Step: 160549
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.758sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.424%
# INFO:tensorflow:Current Loss: 7.299
# INFO:tensorflow:Epoch 5/12, Global Step: 160559
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.750sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.416%
# INFO:tensorflow:Current Loss: 7.021
# INFO:tensorflow:Epoch 5/12, Global Step: 160569
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.774sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.400%
# INFO:tensorflow:Current Loss: 7.095
# INFO:tensorflow:Epoch 5/12, Global Step: 160579
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.725sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.381%
# INFO:tensorflow:Current Loss: 7.178
# INFO:tensorflow:Epoch 5/12, Global Step: 160589
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.784sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.365%
# INFO:tensorflow:Current Loss: 7.077
# INFO:tensorflow:Epoch 5/12, Global Step: 160599
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.799sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.366%
# INFO:tensorflow:Current Loss: 6.720
# INFO:tensorflow:Epoch 5/12, Global Step: 160609
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.759sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.367%
# INFO:tensorflow:Current Loss: 7.247
# INFO:tensorflow:Epoch 5/12, Global Step: 160619
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.772sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.372%
# INFO:tensorflow:Current Loss: 7.100
# INFO:tensorflow:Epoch 5/12, Global Step: 160629
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.753sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.365%
# INFO:tensorflow:Current Loss: 6.502
# INFO:tensorflow:Epoch 5/12, Global Step: 160639
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.792sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.376%
# INFO:tensorflow:Current Loss: 6.947
# INFO:tensorflow:Epoch 5/12, Global Step: 160649
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.755sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.374%
# INFO:tensorflow:Current Loss: 6.367
# INFO:tensorflow:Epoch 5/12, Global Step: 160659
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.780sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.381%
# INFO:tensorflow:Current Loss: 7.074
# INFO:tensorflow:Epoch 5/12, Global Step: 160669
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.787sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.385%
# INFO:tensorflow:Current Loss: 6.867
# INFO:tensorflow:Epoch 5/12, Global Step: 160679
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.756sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.387%
# INFO:tensorflow:Current Loss: 6.283
# INFO:tensorflow:Epoch 5/12, Global Step: 160689
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.822sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.397%
# INFO:tensorflow:Current Loss: 6.894
# INFO:tensorflow:Epoch 5/12, Global Step: 160699
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.759sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.398%
# INFO:tensorflow:Current Loss: 6.807
# INFO:tensorflow:Epoch 5/12, Global Step: 160709
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.786sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.398%
# INFO:tensorflow:Current Loss: 7.101
# INFO:tensorflow:Epoch 5/12, Global Step: 160719
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.788sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.412%
# INFO:tensorflow:Current Loss: 6.645
# INFO:tensorflow:Epoch 5/12, Global Step: 160729
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.842sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.409%
# INFO:tensorflow:Current Loss: 7.328
# INFO:tensorflow:Epoch 5/12, Global Step: 160739
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.799sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.393%
# INFO:tensorflow:Current Loss: 7.162
# INFO:tensorflow:Epoch 5/12, Global Step: 160749
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.770sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.398%
# INFO:tensorflow:Current Loss: 7.031
# INFO:tensorflow:Epoch 5/12, Global Step: 160759
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.812sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.395%
# INFO:tensorflow:Current Loss: 6.844
# INFO:tensorflow:Epoch 5/12, Global Step: 160769
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.793sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.398%
# INFO:tensorflow:Current Loss: 6.950
# INFO:tensorflow:Epoch 5/12, Global Step: 160779
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.845sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.401%
# INFO:tensorflow:Current Loss: 7.256
# INFO:tensorflow:Epoch 5/12, Global Step: 160789
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.760sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.398%
# INFO:tensorflow:Current Loss: 6.837
# INFO:tensorflow:Epoch 5/12, Global Step: 160799
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.803sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.396%
# INFO:tensorflow:Current Loss: 6.670
# INFO:tensorflow:Epoch 5/12, Global Step: 160809
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.787sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.396%
# INFO:tensorflow:Current Loss: 7.324
# INFO:tensorflow:Epoch 5/12, Global Step: 160819
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.801sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.388%
# INFO:tensorflow:Current Loss: 7.001
# INFO:tensorflow:Epoch 5/12, Global Step: 160829
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.777sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.376%
# INFO:tensorflow:Current Loss: 6.986
# INFO:tensorflow:Epoch 5/12, Global Step: 160839
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.765sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.360%
# INFO:tensorflow:Current Loss: 6.855
# INFO:tensorflow:Epoch 5/12, Global Step: 160849
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.770sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.350%
# INFO:tensorflow:Current Loss: 7.041
# INFO:tensorflow:Epoch 5/12, Global Step: 160859
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.795sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.343%
# INFO:tensorflow:Current Loss: 6.790
# INFO:tensorflow:Epoch 5/12, Global Step: 160869
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.813sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.326%
# INFO:tensorflow:Current Loss: 6.925
# INFO:tensorflow:Epoch 5/12, Global Step: 160879
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.751sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.324%
# INFO:tensorflow:Current Loss: 6.892
# INFO:tensorflow:Epoch 5/12, Global Step: 160889
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.804sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.327%
# INFO:tensorflow:Current Loss: 7.062
# INFO:tensorflow:Epoch 5/12, Global Step: 160899
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.787sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.318%
# INFO:tensorflow:Current Loss: 6.926
# INFO:tensorflow:Epoch 5/12, Global Step: 160909
# INFO:tensorflow:Current Learning Rate: 0.00022650013852398843
# INFO:tensorflow:Current Speed: 1.776sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.315%
# INFO:tensorflow:Current Loss: 7.340
# ...
# INFO:tensorflow:Epoch 5/12, Global Step: 192689
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.382sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.734%
# INFO:tensorflow:Current Loss: 7.094
# INFO:tensorflow:Epoch 5/12, Global Step: 192699
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.679sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.735%
# INFO:tensorflow:Current Loss: 7.157
# INFO:tensorflow:Epoch 5/12, Global Step: 192709
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.896sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.735%
# INFO:tensorflow:Current Loss: 7.061
# INFO:tensorflow:Epoch 5/12, Global Step: 192719
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.562sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.736%
# INFO:tensorflow:Current Loss: 6.926
# INFO:tensorflow:Epoch 5/12, Global Step: 192729
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.965sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.737%
# INFO:tensorflow:Current Loss: 7.453
# INFO:tensorflow:Epoch 5/12, Global Step: 192739
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.887sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.737%
# INFO:tensorflow:Current Loss: 6.849
# INFO:tensorflow:Epoch 5/12, Global Step: 192749
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.522sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.738%
# INFO:tensorflow:Current Loss: 6.964
# INFO:tensorflow:Epoch 5/12, Global Step: 192759
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.463sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.738%
# INFO:tensorflow:Current Loss: 7.093
# INFO:tensorflow:Epoch 5/12, Global Step: 192769
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.519sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.739%
# INFO:tensorflow:Current Loss: 7.333
# INFO:tensorflow:Epoch 5/12, Global Step: 192779
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.466sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.739%
# INFO:tensorflow:Current Loss: 6.903
# INFO:tensorflow:Epoch 5/12, Global Step: 192789
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.396sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.740%
# INFO:tensorflow:Current Loss: 7.267
# INFO:tensorflow:Epoch 5/12, Global Step: 192799
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.451sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.740%
# INFO:tensorflow:Current Loss: 7.529
# INFO:tensorflow:Epoch 5/12, Global Step: 192809
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.024sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.740%
# INFO:tensorflow:Current Loss: 7.143
# INFO:tensorflow:Epoch 5/12, Global Step: 192819
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.524sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.740%
# INFO:tensorflow:Current Loss: 7.166
# INFO:tensorflow:Epoch 5/12, Global Step: 192829
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.781sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.740%
# INFO:tensorflow:Current Loss: 7.071
# INFO:tensorflow:Epoch 5/12, Global Step: 192839
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.507sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.740%
# INFO:tensorflow:Current Loss: 7.588
# INFO:tensorflow:Epoch 5/12, Global Step: 192849
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.875sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.740%
# INFO:tensorflow:Current Loss: 7.574
# INFO:tensorflow:Epoch 5/12, Global Step: 192859
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.937sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.741%
# INFO:tensorflow:Current Loss: 7.120
# INFO:tensorflow:Epoch 5/12, Global Step: 192869
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.808sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.741%
# INFO:tensorflow:Current Loss: 7.718
# INFO:tensorflow:Epoch 5/12, Global Step: 192879
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.830sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.741%
# INFO:tensorflow:Current Loss: 7.069
# INFO:tensorflow:Epoch 5/12, Global Step: 192889
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.934sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.742%
# INFO:tensorflow:Current Loss: 7.226
# INFO:tensorflow:Epoch 5/12, Global Step: 192899
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.793sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.742%
# INFO:tensorflow:Current Loss: 7.219
# INFO:tensorflow:Epoch 5/12, Global Step: 192909
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.689sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.742%
# INFO:tensorflow:Current Loss: 7.568
# INFO:tensorflow:Epoch 5/12, Global Step: 192919
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.719sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.743%
# INFO:tensorflow:Current Loss: 7.059
# INFO:tensorflow:Epoch 5/12, Global Step: 192929
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.748sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.744%
# INFO:tensorflow:Current Loss: 6.948
# INFO:tensorflow:Epoch 5/12, Global Step: 192939
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.708sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.745%
# INFO:tensorflow:Current Loss: 6.591
# INFO:tensorflow:Epoch 5/12, Global Step: 192949
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.703sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.745%
# INFO:tensorflow:Current Loss: 6.678
# INFO:tensorflow:Epoch 5/12, Global Step: 192959
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.714sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.746%
# INFO:tensorflow:Current Loss: 7.021
# INFO:tensorflow:Epoch 5/12, Global Step: 192969
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.758sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.746%
# INFO:tensorflow:Current Loss: 7.168
# INFO:tensorflow:Epoch 5/12, Global Step: 192979
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.126sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.747%
# INFO:tensorflow:Current Loss: 7.528
# INFO:tensorflow:Epoch 5/12, Global Step: 192989
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.707sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.747%
# INFO:tensorflow:Current Loss: 7.426
# INFO:tensorflow:Epoch 5/12, Global Step: 192999
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.752sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.748%
# INFO:tensorflow:Current Loss: 6.912
# INFO:tensorflow:Epoch 5/12, Global Step: 193009
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.757sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.748%
# INFO:tensorflow:Current Loss: 7.433
# INFO:tensorflow:Epoch 5/12, Global Step: 193019
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.792sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.747%
# INFO:tensorflow:Current Loss: 6.810
# INFO:tensorflow:Epoch 5/12, Global Step: 193029
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.713sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.748%
# INFO:tensorflow:Current Loss: 7.155
# INFO:tensorflow:Epoch 5/12, Global Step: 193039
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.712sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.749%
# INFO:tensorflow:Current Loss: 7.018
# INFO:tensorflow:Epoch 5/12, Global Step: 193049
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.768sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.749%
# INFO:tensorflow:Current Loss: 7.405
# INFO:tensorflow:Epoch 5/12, Global Step: 193059
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.766sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.750%
# INFO:tensorflow:Current Loss: 6.955
# INFO:tensorflow:Epoch 5/12, Global Step: 193069
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.740sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.750%
# INFO:tensorflow:Current Loss: 7.100
# INFO:tensorflow:Epoch 5/12, Global Step: 193079
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.721sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.750%
# INFO:tensorflow:Current Loss: 7.445
# INFO:tensorflow:Epoch 5/12, Global Step: 193089
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.781sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.750%
# INFO:tensorflow:Current Loss: 8.036
# INFO:tensorflow:Epoch 5/12, Global Step: 193099
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.743sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.750%
# INFO:tensorflow:Current Loss: 7.323
# INFO:tensorflow:Epoch 5/12, Global Step: 193109
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.771sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.750%
# INFO:tensorflow:Current Loss: 7.138
# INFO:tensorflow:Epoch 5/12, Global Step: 193119
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.800sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.750%
# INFO:tensorflow:Current Loss: 7.423
# INFO:tensorflow:Epoch 5/12, Global Step: 193129
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.752sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.750%
# INFO:tensorflow:Current Loss: 7.416
# INFO:tensorflow:Epoch 5/12, Global Step: 193139
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.712sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.750%
# INFO:tensorflow:Current Loss: 7.210
# INFO:tensorflow:Epoch 5/12, Global Step: 193149
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.542sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.750%
# INFO:tensorflow:Current Loss: 7.128
# INFO:tensorflow:Epoch 5/12, Global Step: 193159
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.804sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.750%
# INFO:tensorflow:Current Loss: 7.057
# INFO:tensorflow:Epoch 5/12, Global Step: 193169
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.198sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.751%
# INFO:tensorflow:Current Loss: 7.088
# INFO:tensorflow:Epoch 5/12, Global Step: 193179
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.719sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.752%
# INFO:tensorflow:Current Loss: 7.514
# INFO:tensorflow:Epoch 5/12, Global Step: 193189
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.689sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.752%
# INFO:tensorflow:Current Loss: 7.315
# INFO:tensorflow:Epoch 5/12, Global Step: 193199
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.787sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.751%
# INFO:tensorflow:Current Loss: 7.509
# INFO:tensorflow:Epoch 5/12, Global Step: 193209
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.730sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.752%
# INFO:tensorflow:Current Loss: 7.166
# INFO:tensorflow:Epoch 5/12, Global Step: 193219
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.839sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.752%
# INFO:tensorflow:Current Loss: 7.199
# INFO:tensorflow:Epoch 5/12, Global Step: 193229
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.779sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.752%
# INFO:tensorflow:Current Loss: 7.190
# INFO:tensorflow:Epoch 5/12, Global Step: 193239
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.659sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.752%
# INFO:tensorflow:Current Loss: 7.195
# INFO:tensorflow:Epoch 5/12, Global Step: 193249
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.183sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.753%
# INFO:tensorflow:Current Loss: 7.082
# INFO:tensorflow:Epoch 5/12, Global Step: 193259
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.790sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.753%
# INFO:tensorflow:Current Loss: 6.631
# INFO:tensorflow:Epoch 5/12, Global Step: 193269
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.446sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.754%
# INFO:tensorflow:Current Loss: 7.300
# INFO:tensorflow:Epoch 5/12, Global Step: 193279
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.757sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.754%
# INFO:tensorflow:Current Loss: 7.062
# INFO:tensorflow:Epoch 5/12, Global Step: 193289
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.411sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.754%
# INFO:tensorflow:Current Loss: 7.465
# INFO:tensorflow:Epoch 5/12, Global Step: 193299
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 1.781sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.754%
# INFO:tensorflow:Current Loss: 7.369
# INFO:tensorflow:Epoch 5/12, Global Step: 193309
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.322sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.754%
# INFO:tensorflow:Current Loss: 7.278
# INFO:tensorflow:Epoch 5/12, Global Step: 193319
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.439sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.754%
# INFO:tensorflow:Current Loss: 7.379
# INFO:tensorflow:Epoch 5/12, Global Step: 193329
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
# INFO:tensorflow:Current Speed: 2.532sec/batch
# INFO:tensorflow:Current Streaming Accuracy: 31.754%
# INFO:tensorflow:Current Loss: 6.949
# INFO:tensorflow:Epoch 5/12, Global Step: 193339
# INFO:tensorflow:Current Learning Rate: 0.00016622936527710408
